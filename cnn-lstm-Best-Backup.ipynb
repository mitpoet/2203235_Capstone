# %% [markdown]
# # Import Libaries

# %%
import numpy as np
import pandas as pd 
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv('../../datasets/meta.csv')
data.head()
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %% [markdown]
# # Data Preprocessing

# %%
# Reset index
data.reset_index(drop=True, inplace=True)

# Select numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Fill NaN values in numeric columns with the mean of those columns
data[numeric_data.columns] = data[numeric_data.columns].fillna(numeric_data.mean())

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Calculate moving average
ma_day = [5, 10, 20, 50]  # Common short-term and long-term windows
for ma in ma_day:
    column_name = f"MA for {ma} days"
    data[column_name] = data['Close'].rolling(window=ma).mean()

# Calculate Exponential moving average
for ma in ma_day:
    column_name = f"EMA for {ma} days"
    data[column_name] = data['Close'].ewm(span=ma, adjust=False).mean()

# Calculate RSI
def compute_RSI(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data['RSI_14'] = compute_RSI(data)

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2

# %%
# Plot the data
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date    Open     High       Low     Close     Volume  \
# 0     2012-05-18   42.05   45.000   38.0000   38.2318  573576400
# 1     2012-05-21   36.53   36.660   33.0000   34.0300  168192700
# 2     2012-05-22   32.61   33.590   30.9400   31.0000  101786600
# 3     2012-05-23   31.37   32.500   31.3600   32.0000   73600000
# 4     2012-05-24   32.95   33.210   31.7700   33.0300   50237200
# ...          ...     ...      ...       ...       ...        ...
# 2668  2022-12-23  116.03  118.175  115.5350  118.0400   17796625
# 2669  2022-12-27  117.93  118.600  116.0501  116.8800   21392311
# 2670  2022-12-28  116.25  118.150  115.5100  115.6200   19612473
# 2671  2022-12-29  116.40  121.030  115.7700  120.2600   22366192
# 2672  2022-12-30  118.16  120.420  117.7400  120.3400   19583825
#
#       MA for 5 days  MA for 10 days  MA for 20 days  MA for 50 days  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4          33.65836             NaN             NaN             NaN
# ...             ...             ...             ...             ...
# 2668      117.29800         117.852         117.025        114.2838
# 2669      117.77800         118.069         117.430        114.0862
# 2670      117.48400         117.616         117.738        113.7178
# 2671      117.58400         117.483         117.846        113.4670
# 2672      118.22800         117.902         117.841        113.2092
#
#       EMA for 5 days  EMA for 10 days  EMA for 20 days  EMA for 50 days  \
# 0          38.231800        38.231800        38.231800        38.231800
# 1          36.831200        37.467836        37.831629        38.067024
# 2          34.887467        36.291866        37.180997        37.789885
# 3          33.924978        35.511527        36.687569        37.562831
# 4          33.626652        35.060340        36.339229        37.385073
# ...              ...              ...              ...              ...
# 2668      117.800705       117.531164       116.637103       119.704974
# 2669      117.493804       117.412770       116.660236       119.594191
# 2670      116.869202       117.086812       116.561166       119.438340
# 2671      117.999468       117.663755       116.913436       119.470562
# 2672      118.779646       118.150345       117.239776       119.504658
#
#          RSI_14      MACD
# 0           NaN  0.000000
# 1           NaN -0.335186
# 2           NaN -0.835686
# 3           NaN -1.138520
# 4           NaN -1.280644
# ...         ...       ...
# 2668  44.652862  0.867627
# 2669  54.070796  0.765449
# 546  2014-07-23  69.740  71.33  69.610  71.29   77435900       68.95796
# 547  2014-07-24  75.960  76.74  74.510  74.98  124006900       70.67198
# 548  2014-07-25  74.990  75.67  74.662  75.19   45823100       72.02600
#
#      MA for 10 days  MA for 20 days  MA for 50 days  EMA for 5 days  \
# 49         27.52000       29.237800       29.838636       25.546291
# 50         26.88200       28.784750       29.508200       24.267527
# 51         26.05900       28.268750       29.245200       23.138351
# 52         25.16300       27.697250       29.026000       22.105568
# 53         24.39600       27.165250       28.807800       21.767045
# ..              ...             ...             ...             ...
# 544        66.58973       66.626865       64.001716       68.007206
# 545        67.24073       66.821865       64.242316       68.428138
# 546        67.87273       67.100365       64.471516       69.382092
# 547        68.88348       67.477365       64.774516       71.248061
# 548        69.76848       67.880365       65.093716       72.562041
#
#      EMA for 10 days  EMA for 20 days  EMA for 50 days     RSI_14      MACD
# 49         27.046144        28.449746        30.538853  15.733114 -1.525536
# 50         26.075936        27.807865        30.192623  14.602446 -1.869091
# 51         25.131220        27.148068        29.827422  13.890909 -2.183168
# 52         24.205544        26.471110        29.443602  13.172414 -2.471369
# 53         23.639081        25.958623        29.116010  22.638623 -2.585243
# ..               ...              ...              ...        ...       ...
# 544        67.283914        66.478537        64.769416  56.251778  1.037495
# 545        67.645020        66.744391        64.945909  53.726471  1.134074
# 546        68.307744        67.177306        65.194697  64.538726  1.357958
# 547        69.520881        67.920420        65.578435  71.536342  1.812249
# 548        70.551630        68.612761        65.955359  75.534944  2.164275
#
# [500 rows x 16 columns]

# %%
# Adapted from the foundation code, but added own improvements

feature_columns = [ # Based on SHAP
    'Close',          # Close price of the day
    'Low',            # Low price of the day
    'High',           # High price of the day
    'Open',           # Open price of the day
    'EMA for 5 days', # Short-term trend indicator
    'MA for 5 days',  # Short-term trend indicator
    'RSI_14'          # Momentum indicator
]


X = []
Y = []
window_size = 15

# Iterating through the dataset to create inputs and targets
for i in range(1, len(df) - window_size - 1, 1):
    first_close = df.iloc[i, df.columns.get_loc('Close')]  # Normalize using "Close" price
    temp = []
    temp2 = []
    
    for j in range(window_size):
        # Normalize each feature in the feature_columns list
        normalized_features = []
        for feature in feature_columns:
            if feature == 'Close':
                # Normalize "Close" relative to the first_close
                normalized_value = (df.iloc[i + j, df.columns.get_loc(feature)] - first_close) / first_close
            else:
                # For other features, normalize them directly (or use their raw values if normalization isn't required)
                normalized_value = df.iloc[i + j, df.columns.get_loc(feature)]
            normalized_features.append(normalized_value)
        
        # Append the normalized features for this time step
        temp.append(normalized_features)
    
    # Calculate the target (normalized change in "Close" price)
    target = (df.iloc[i + window_size, df.columns.get_loc('Close')] - first_close) / first_close
    temp2.append(target)
    
    # Append the input and target to X and Y
    X.append(np.array(temp))  # Each sample has shape (window_size, len(feature_columns))
    Y.append(np.array(temp2).reshape(1, 1))

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# Converting lists to numpy arrays
train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

# Verify the shape of train_X
print("Shape of train_X before reshaping:", train_X.shape)

# Reshaping the data for CNN models
train_X = train_X.reshape(train_X.shape[0], 1, train_X.shape[1], train_X.shape[2])  
test_X = test_X.reshape(test_X.shape[0], 1, test_X.shape[1], test_X.shape[2])

# Printing the number of training and testing samples
print("Shape of train_X after reshaping:", train_X.shape)
print("Shape of test_X after reshaping:", test_X.shape)
print("Number of training samples:", len(train_X))
print("Number of testing samples:", len(test_X))
# Out:
# Shape of train_X before reshaping: (2085, 15, 7)
# Shape of train_X after reshaping: (2085, 1, 15, 7)
# Shape of test_X after reshaping: (522, 1, 15, 7)
# Number of training samples: 2085
# Number of testing samples: 522

# %%
# Check if there are any NaN values

print(np.isnan(train_X).any(), np.isnan(train_Y).any())
print(np.isinf(train_X).any(), np.isinf(train_Y).any())
# Out:
# False False
# False False

# %%
# Adapted from the foundation code, but added own improvements

import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam


# Create the model
model = tf.keras.Sequential()

# Enhanced CNN layers with BatchNormalization and LeakyReLU
model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                               input_shape=(None, 100, 1))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Flatten()))

# Enhanced LSTM layers 
model.add(Bidirectional(LSTM(128, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(64, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Dense layers with regularization
model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# Optimizer with gradient clipping
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

model.compile(optimizer=optimizer,
             loss='mse',
             metrics=['mse', 'mae'])

# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )
]

# Train the model
history = model.fit(
    train_X, 
    train_Y,
    validation_data=(test_X, test_Y),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/100
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - loss: 1.8768 - mae: 0.9832 - mse: 1.5862 - val_loss: 0.2580 - val_mae: 0.2070 - val_mse: 0.0496 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5241 - mae: 0.4448 - mse: 0.3235 - val_loss: 0.2243 - val_mae: 0.1652 - val_mse: 0.0333 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3591 - mae: 0.3292 - mse: 0.1690 - val_loss: 0.2101 - val_mae: 0.1272 - val_mse: 0.0220 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3062 - mae: 0.2653 - mse: 0.1187 - val_loss: 0.2034 - val_mae: 0.1138 - val_mse: 0.0177 - learning_rate: 0.0010
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2757 - mae: 0.2321 - mse: 0.0906 - val_loss: 0.1961 - val_mae: 0.0947 - val_mse: 0.0131 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2462 - mae: 0.1948 - mse: 0.0640 - val_loss: 0.1925 - val_mae: 0.0925 - val_mse: 0.0126 - learning_rate: 0.0010
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2253 - mae: 0.1669 - mse: 0.0462 - val_loss: 0.1898 - val_mae: 0.0956 - val_mse: 0.0132 - learning_rate: 0.0010
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2136 - mae: 0.1509 - mse: 0.0378 - val_loss: 0.1834 - val_mae: 0.0793 - val_mse: 0.0103 - learning_rate: 0.0010
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2045 - mae: 0.1387 - mse: 0.0323 - val_loss: 0.1807 - val_mae: 0.0861 - val_mse: 0.0113 - learning_rate: 0.0010
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1936 - mae: 0.1212 - mse: 0.0252 - val_loss: 0.1737 - val_mae: 0.0664 - val_mse: 0.0083 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1854 - mae: 0.1126 - mse: 0.0210 - val_loss: 0.1702 - val_mae: 0.0714 - val_mse: 0.0089 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1798 - mae: 0.1054 - mse: 0.0195 - val_loss: 0.1661 - val_mae: 0.0685 - val_mse: 0.0090 - learning_rate: 0.0010
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1707 - mae: 0.0930 - mse: 0.0146 - val_loss: 0.1616 - val_mae: 0.0708 - val_mse: 0.0088 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1653 - mae: 0.0906 - mse: 0.0137 - val_loss: 0.1573 - val_mae: 0.0744 - val_mse: 0.0090 - learning_rate: 0.0010
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0495 - mae: 0.0395 - mse: 0.0030 - val_loss: 0.0503 - val_mae: 0.0576 - val_mse: 0.0059 - learning_rate: 0.0010
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0462 - mae: 0.0362 - mse: 0.0026 - val_loss: 0.0477 - val_mae: 0.0582 - val_mse: 0.0061 - learning_rate: 0.0010
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0437 - mae: 0.0374 - mse: 0.0028 - val_loss: 0.0445 - val_mae: 0.0612 - val_mse: 0.0057 - learning_rate: 0.0010
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0410 - mae: 0.0366 - mse: 0.0028 - val_loss: 0.0405 - val_mae: 0.0429 - val_mse: 0.0041 - learning_rate: 0.0010
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0383 - mae: 0.0343 - mse: 0.0026 - val_loss: 0.0401 - val_mae: 0.0652 - val_mse: 0.0061 - learning_rate: 0.0010
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0358 - mae: 0.0344 - mse: 0.0024 - val_loss: 0.0476 - val_mae: 0.1107 - val_mse: 0.0159 - learning_rate: 0.0010
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0341 - mae: 0.0376 - mse: 0.0028 - val_loss: 0.0340 - val_mae: 0.0510 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0317 - mae: 0.0348 - mse: 0.0025 - val_loss: 0.0344 - val_mae: 0.0690 - val_mse: 0.0066 - learning_rate: 0.0010
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0301 - mae: 0.0368 - mse: 0.0027 - val_loss: 0.0296 - val_mae: 0.0415 - val_mse: 0.0036 - learning_rate: 0.0010
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0279 - mae: 0.0348 - mse: 0.0024 - val_loss: 0.0302 - val_mae: 0.0545 - val_mse: 0.0058 - learning_rate: 0.0010
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0266 - mae: 0.0357 - mse: 0.0026 - val_loss: 0.0377 - val_mae: 0.1058 - val_mse: 0.0148 - learning_rate: 0.0010
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0257 - mae: 0.0393 - mse: 0.0031 - val_loss: 0.0252 - val_mae: 0.0437 - val_mse: 0.0038 - learning_rate: 0.0010
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0235 - mae: 0.0346 - mse: 0.0025 - val_loss: 0.0346 - val_mae: 0.1073 - val_mse: 0.0146 - learning_rate: 0.0010
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0234 - mae: 0.0427 - mse: 0.0036 - val_loss: 0.0252 - val_mae: 0.0602 - val_mse: 0.0062 - learning_rate: 0.0010
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0218 - mae: 0.0392 - mse: 0.0029 - val_loss: 0.0220 - val_mae: 0.0435 - val_mse: 0.0041 - learning_rate: 0.0010
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0211 - mae: 0.0403 - mse: 0.0033 - val_loss: 0.0221 - val_mae: 0.0559 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0193 - mae: 0.0368 - mse: 0.0028 - val_loss: 0.0229 - val_mae: 0.0730 - val_mse: 0.0073 - learning_rate: 0.0010
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0181 - mae: 0.0357 - mse: 0.0026 - val_loss: 0.0206 - val_mae: 0.0577 - val_mse: 0.0061 - learning_rate: 0.0010
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0166 - mae: 0.0334 - mse: 0.0024 - val_loss: 0.0228 - val_mae: 0.0803 - val_mse: 0.0093 - learning_rate: 0.0010
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0159 - mae: 0.0348 - mse: 0.0025 - val_loss: 0.0299 - val_mae: 0.1155 - val_mse: 0.0171 - learning_rate: 0.0010
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0155 - mae: 0.0365 - mse: 0.0028 - val_loss: 0.0190 - val_mae: 0.0606 - val_mse: 0.0069 - learning_rate: 0.0010
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0144 - mae: 0.0352 - mse: 0.0025 - val_loss: 0.0158 - val_mae: 0.0487 - val_mse: 0.0045 - learning_rate: 0.0010
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0134 - mae: 0.0336 - mse: 0.0023 - val_loss: 0.0230 - val_mae: 0.0974 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0140 - mae: 0.0413 - mse: 0.0034 - val_loss: 0.0186 - val_mae: 0.0777 - val_mse: 0.0086 - learning_rate: 0.0010
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0127 - mae: 0.0361 - mse: 0.0029 - val_loss: 0.0141 - val_mae: 0.0534 - val_mse: 0.0048 - learning_rate: 0.0010
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0123 - mae: 0.0386 - mse: 0.0031 - val_loss: 0.0131 - val_mae: 0.0458 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0111 - mae: 0.0357 - mse: 0.0025 - val_loss: 0.0124 - val_mae: 0.0464 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0107 - mae: 0.0350 - mse: 0.0025 - val_loss: 0.0131 - val_mae: 0.0571 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0110 - mae: 0.0390 - mse: 0.0031 - val_loss: 0.0130 - val_mae: 0.0601 - val_mse: 0.0054 - learning_rate: 0.0010
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0105 - mae: 0.0379 - mse: 0.0030 - val_loss: 0.0202 - val_mae: 0.1028 - val_mse: 0.0131 - learning_rate: 0.0010
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0096 - mae: 0.0348 - mse: 0.0026 - val_loss: 0.0130 - val_mae: 0.0604 - val_mse: 0.0061 - learning_rate: 0.0010
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0094 - mae: 0.0370 - mse: 0.0027 - val_loss: 0.0149 - val_mae: 0.0805 - val_mse: 0.0084 - learning_rate: 0.0010
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0088 - mae: 0.0343 - mse: 0.0025 - val_loss: 0.0088 - val_mae: 0.0397 - val_mse: 0.0030 - learning_rate: 2.0000e-04
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0077 - mae: 0.0317 - mse: 0.0019 - val_loss: 0.0091 - val_mae: 0.0443 - val_mse: 0.0035 - learning_rate: 2.0000e-04
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0078 - mae: 0.0328 - mse: 0.0022 - val_loss: 0.0089 - val_mae: 0.0474 - val_mse: 0.0035 - learning_rate: 2.0000e-04
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0072 - mae: 0.0299 - mse: 0.0018 - val_loss: 0.0092 - val_mae: 0.0469 - val_mse: 0.0039 - learning_rate: 2.0000e-04
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - mae: 0.0316 - mse: 0.0021 - val_loss: 0.0090 - val_mae: 0.0456 - val_mse: 0.0038 - learning_rate: 2.0000e-04
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0072 - mae: 0.0307 - mse: 0.0020 - val_loss: 0.0101 - val_mae: 0.0548 - val_mse: 0.0050 - learning_rate: 2.0000e-04
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0067 - mae: 0.0301 - mse: 0.0017 - val_loss: 0.0077 - val_mae: 0.0385 - val_mse: 0.0027 - learning_rate: 4.0000e-05
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0067 - mae: 0.0305 - mse: 0.0018 - val_loss: 0.0073 - val_mae: 0.0348 - val_mse: 0.0024 - learning_rate: 4.0000e-05
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0066 - mae: 0.0292 - mse: 0.0017 - val_loss: 0.0075 - val_mae: 0.0353 - val_mse: 0.0026 - learning_rate: 4.0000e-05
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0066 - mae: 0.0290 - mse: 0.0017 - val_loss: 0.0084 - val_mae: 0.0464 - val_mse: 0.0036 - learning_rate: 4.0000e-05
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0064 - mae: 0.0277 - mse: 0.0016 - val_loss: 0.0078 - val_mae: 0.0441 - val_mse: 0.0030 - learning_rate: 4.0000e-05
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0066 - mae: 0.0295 - mse: 0.0018 - val_loss: 0.0073 - val_mae: 0.0346 - val_mse: 0.0026 - learning_rate: 4.0000e-05
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0064 - mae: 0.0287 - mse: 0.0017 - val_loss: 0.0070 - val_mae: 0.0332 - val_mse: 0.0022 - learning_rate: 4.0000e-05
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0065 - mae: 0.0290 - mse: 0.0017 - val_loss: 0.0071 - val_mae: 0.0329 - val_mse: 0.0024 - learning_rate: 4.0000e-05
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0065 - mae: 0.0294 - mse: 0.0018 - val_loss: 0.0073 - val_mae: 0.0361 - val_mse: 0.0026 - learning_rate: 4.0000e-05
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0060 - mae: 0.0266 - mse: 0.0014 - val_loss: 0.0072 - val_mae: 0.0384 - val_mse: 0.0025 - learning_rate: 4.0000e-05
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - mae: 0.0278 - mse: 0.0015 - val_loss: 0.0072 - val_mae: 0.0346 - val_mse: 0.0025 - learning_rate: 4.0000e-05
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0061 - mae: 0.0268 - mse: 0.0014 - val_loss: 0.0077 - val_mae: 0.0452 - val_mse: 0.0031 - learning_rate: 4.0000e-05
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0062 - mae: 0.0288 - mse: 0.0016 - val_loss: 0.0072 - val_mae: 0.0394 - val_mse: 0.0026 - learning_rate: 8.0000e-06
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0060 - mae: 0.0268 - mse: 0.0014 - val_loss: 0.0071 - val_mae: 0.0384 - val_mse: 0.0025 - learning_rate: 8.0000e-06
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0065 - mae: 0.0300 - mse: 0.0019 - val_loss: 0.0068 - val_mae: 0.0349 - val_mse: 0.0023 - learning_rate: 8.0000e-06
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0062 - mae: 0.0287 - mse: 0.0017 - val_loss: 0.0069 - val_mae: 0.0367 - val_mse: 0.0024 - learning_rate: 8.0000e-06
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - mae: 0.0279 - mse: 0.0016 - val_loss: 0.0070 - val_mae: 0.0375 - val_mse: 0.0024 - learning_rate: 8.0000e-06
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0059 - mae: 0.0269 - mse: 0.0014 - val_loss: 0.0068 - val_mae: 0.0344 - val_mse: 0.0023 - learning_rate: 8.0000e-06
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0060 - mae: 0.0264 - mse: 0.0015 - val_loss: 0.0067 - val_mae: 0.0337 - val_mse: 0.0022 - learning_rate: 8.0000e-06
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0061 - mae: 0.0273 - mse: 0.0016 - val_loss: 0.0069 - val_mae: 0.0379 - val_mse: 0.0024 - learning_rate: 8.0000e-06
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0059 - mae: 0.0265 - mse: 0.0013 - val_loss: 0.0069 - val_mae: 0.0374 - val_mse: 0.0024 - learning_rate: 8.0000e-06
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0061 - mae: 0.0283 - mse: 0.0016 - val_loss: 0.0067 - val_mae: 0.0337 - val_mse: 0.0022 - learning_rate: 8.0000e-06
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0059 - mae: 0.0263 - mse: 0.0014 - val_loss: 0.0066 - val_mae: 0.0330 - val_mse: 0.0021 - learning_rate: 8.0000e-06
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0058 - mae: 0.0264 - mse: 0.0014 - val_loss: 0.0070 - val_mae: 0.0389 - val_mse: 0.0025 - learning_rate: 8.0000e-06

# %%
# plot train val loss 
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

print("Training Loss:", history.history.get('loss', []))
print("Validation Loss:", history.history.get('val_loss', []))
# Out:
# Training Loss: [1.3352069854736328, 0.47983765602111816, 0.34082087874412537, 0.30104750394821167, 0.263965368270874, 0.23969727754592896, 0.22273869812488556, 0.21109379827976227, 0.20187239348888397, 0.19170592725276947, 0.1835443526506424, 0.17688901722431183, 0.16905751824378967, 0.1638549268245697, 0.15762291848659515, 0.15127451717853546, 0.1463138312101364, 0.14204490184783936, 0.13624271750450134, 0.13037964701652527, 0.1250038743019104, 0.11984743922948837, 0.11452258378267288, 0.1099565327167511, 0.10480110347270966, 0.10011827945709229, 0.0953313410282135, 0.09064140915870667, 0.08650264889001846, 0.08206552267
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# mae
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0245 - mse: 0.0011
# [0.00662815710529685, 0.0021315126214176416, 0.032961782068014145]

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.787061
# R2 Score: 0.787061
# Max Error: 0.278699

# %%
# make predictions
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Create figure and axis with specified size
    plt.figure(figsize=(15, 7))
    
    # Plot actual prices
    plt.plot(test_label, label='Actual Price', color='green')
    
    # Plot predicted prices
    plt.plot(predicted, label='Predicted Price', color='red')
    
    # Customize the plot
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add margins for better visibility
    plt.margins(x=0.02)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Show plot
    plt.show()

def plot_predictions_with_dates(test_label, predicted, dates, title="Stock Price Prediction"):
    plt.figure(figsize=(15, 6))
    
    # Plot with dates
    plt.plot(dates, test_label, label='Actual Price', color='blue', linewidth=2)
    plt.plot(dates, predicted, label='Predicted Price', color='red', linestyle='--', linewidth=2)
    
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Format date axis
    plt.gcf().autofmt_xdate()  # Angle and align the tick labels
    
    plt.tight_layout()
    plt.show()

# %%
from scipy.signal import savgol_filter

def plot_predictions(test_label, predicted, title="Actual V Stock Price Prediction"):
    # Apply smoothing to both lines
    window_length = 5  # Must be odd; adjust this value to control smoothing amount
    polyorder = 1
    
    # Smooth both actual and predicted values
    test_label_smooth = savgol_filter(test_label.flatten(), window_length, polyorder)
    predicted_smooth = savgol_filter(predicted.flatten(), window_length, polyorder)
    
    plt.figure(figsize=(15, 6))
    
    # Plot smoothed lines
    plt.plot(test_label_smooth, label='Actual Price', color='red')
    plt.plot(predicted_smooth, label='Predicted Price', color='blue')
    
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_predictions(test_label, predicted, "Actual V Stock Price Prediction")

# %%
# Performance Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Calculate performance metrics
mse = mean_squared_error(test_label, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_label, predicted)
mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100

# Print performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Squared Error (MSE): 102.26663512056366
# Root Mean Squared Error (RMSE): 10.112696728398596
# Mean Absolute Error (MAE): 7.493800442257126
# Mean Absolute Percentage Error (MAPE): 3.54%

# %%
# save the model
model.save('improved_cnn_lstm_model.keras')

# %%
def save_metrics(test_label, predicted, model_name, stock_name):
    """
    Calculate metrics and save to CSV 
    """
    # Calculate metrics
    mse = mean_squared_error(test_label, predicted)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(test_label, predicted)
    mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100
    r2 = r2_score(test_label, predicted)
    
    # Round to 4 decimal places
    rmse = round(rmse, 4)
    mae = round(mae, 4)
    mape = round(mape, 4)
    r2 = round(r2, 4)
    mse = round(mse, 4)
    
    # Create metrics dictionary
    metrics = {
        'Model': [model_name],
        'Stock': [stock_name],
        'RMSE': [rmse],
        'MAE': [mae],
        'MAPE': [mape],
        'R2': [r2]
    }
    
    # Convert to DataFrame
    df_metrics = pd.DataFrame(metrics)
    
    # Save to CSV
    filename = f'metrics_{model_name}_{stock_name}.csv'
    df_metrics.to_csv(filename, index=False)
    
    # Print metrics
    print(f"\nMetrics for {model_name} on {stock_name}:")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
    print(f"R² Score: {r2:.4f}")

# %%
# Save metrics to CSV
save_metrics(test_label, predicted, "CNN-LSTM-Improved", "META")
# Out:
# Metrics for CNN-LSTM-Improved on META:
# Mean Squared Error (MSE): 102.2666
# Root Mean Squared Error (RMSE): 10.1127
# Mean Absolute Error (MAE): 7.4938
# Mean Absolute Percentage Error (MAPE): 3.5425%
# R² Score: 0.9849

# %%
def save_prediction_errors(predictions, actual_values, model_name, stock_name):
    """
    Save prediction errors for error distribution analysis
    """
    # Calculate errors
    errors = predictions - actual_values
    
    # Save to numpy file
    filename = f'errors_{model_name}_{stock_name}.npy'
    np.save(filename, errors)
    
    print(f"Saved prediction errors to {filename}")

# Save the errors
save_prediction_errors(
    predictions=predicted,
    actual_values=test_label,
    model_name="CNN-LSTM-Improved",
    stock_name="META"  
    )
# Out:
# Saved prediction errors to errors_CNN-LSTM-Improved_META.npy

# %%
import pickle


# Save the history dictionary
with open('cnn-lstm-best.pkl', 'wb') as file:  
    pickle.dump(history.history, file)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats

# Calculate residuals
residuals = test_label.flatten() - predicted.flatten()

# Create figure
plt.figure(figsize=(20, 12))

# 1. Residuals over time
plt.subplot(2, 2, 1)
plt.plot(residuals, 'b-', linewidth=1)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Time')
plt.ylabel('Residual (Actual - Predicted)')
plt.grid(True, alpha=0.3)

# 2. Histogram of residuals
plt.subplot(2, 2, 2)
sns.histplot(residuals, kde=True, bins=30)
plt.axvline(x=0, color='r', linestyle='--')
plt.title('Distribution of Residuals', fontsize=14, fontweight='bold')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

# 3. Q-Q plot for normality assessment
plt.subplot(2, 2, 3)
stats.probplot(residuals, plot=plt)
plt.title('Q-Q Plot (Normality Check)', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

# 4. Residuals vs Predicted values
plt.subplot(2, 2, 4)
plt.scatter(predicted.flatten(), residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals vs Predicted Values', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Price')
plt.ylabel('Residual')
plt.grid(True, alpha=0.3)

# Add summary statistics textbox
stats_text = (
    f"Mean Residual: {np.mean(residuals):.4f}\n"
    f"Std Dev: {np.std(residuals):.4f}\n"
    f"RMSE: {np.sqrt(np.mean(residuals**2)):.4f}\n"
    f"MAE: {np.mean(np.abs(residuals)):.4f}"
)
props = dict(boxstyle='round', facecolor='white', alpha=0.8)
plt.subplot(2, 2, 2)
plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, 
         fontsize=12, verticalalignment='top', bbox=props)

plt.tight_layout()
plt.savefig('residual_analysis.png', dpi=300)
plt.show()

# %%
# Plot the model architecture
print(model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_26             │ (None, 1, 15, 64)      │         1,408 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_27             │ (None, 1, 15, 64)      │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_28             │ (None, 1, 15, 64)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_29             │ (None, 1, 7, 64)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_30             │ (None, 1, 7, 128)      │        24,704 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_31             │ (None, 1, 7, 128)      │           512 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_32             │ (None, 1, 7, 128)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_33             │ (None, 1, 3, 128)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_34             │ (None, 1, 3, 64)       │        24,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_35             │ (None, 1, 3, 64)       │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_36             │ (None, 1, 3, 64)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_37             │ (None, 1, 1, 64)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_38             │ (None, 1, 64)          │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 1, 256)         │       197,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 1, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 1, 128)         │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1, 32)          │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 1, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 1, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1, 1)           │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,256,069 (4.79 MB)
#  Trainable params: 418,241 (1.60 MB)
#  Non-trainable params: 1,344 (5.25 KB)
#  Optimizer params: 836,484 (3.19 MB)
# None
