# %%
import numpy as np # linear algebra
import pandas as pd 
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('./meta.csv')
data.head()
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Reset index
data.reset_index(drop=True, inplace=True)

# Select numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Fill NaN values in numeric columns with the mean of those columns
data[numeric_data.columns] = data[numeric_data.columns].fillna(numeric_data.mean())

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Calculate moving average
ma_day = [5, 10, 20, 50]  # Common short-term and long-term windows
for ma in ma_day:
    column_name = f"MA for {ma} days"
    data[column_name] = data['Close'].rolling(window=ma).mean()

# Calculate Exponential moving average
for ma in ma_day:
    column_name = f"EMA for {ma} days"
    data[column_name] = data['Close'].ewm(span=ma, adjust=False).mean()

# Volatility (Standard Deviation): Capture price fluctuations:
# for ma in ma_day:
#     column_name = f"Volatility_{ma}d"
#     data[column_name] = data['Close'].rolling(window=ma).std()

# Calculate RSI
def compute_RSI(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data['RSI_14'] = compute_RSI(data)

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2
data['Signal_Line'] = data['MACD'].ewm(span=9, adjust=False).mean()

# # Trading Volume Moving Average: Add moving averages for the Volume
# for ma in ma_day:
#     data[f"Volume_MA_{ma}"] = data['Volume'].rolling(window=ma).mean()

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date    Open     High       Low     Close     Volume  \
# 0     2012-05-18   42.05   45.000   38.0000   38.2318  573576400
# 1     2012-05-21   36.53   36.660   33.0000   34.0300  168192700
# 2     2012-05-22   32.61   33.590   30.9400   31.0000  101786600
# 3     2012-05-23   31.37   32.500   31.3600   32.0000   73600000
# 4     2012-05-24   32.95   33.210   31.7700   33.0300   50237200
# ...          ...     ...      ...       ...       ...        ...
# 2668  2022-12-23  116.03  118.175  115.5350  118.0400   17796625
# 2669  2022-12-27  117.93  118.600  116.0501  116.8800   21392311
# 2670  2022-12-28  116.25  118.150  115.5100  115.6200   19612473
# 2671  2022-12-29  116.40  121.030  115.7700  120.2600   22366192
# 2672  2022-12-30  118.16  120.420  117.7400  120.3400   19583825
#
#       MA for 5 days  MA for 10 days  MA for 20 days  MA for 50 days  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4          33.65836             NaN             NaN             NaN
# ...             ...             ...             ...             ...
# 2668      117.29800         117.852         117.025        114.2838
# 2669      117.77800         118.069         117.430        114.0862
# 2670      117.48400         117.616         117.738        113.7178
# 2671      117.58400         117.483         117.846        113.4670
# 2672      118.22800         117.902         117.841        113.2092
#
#       EMA for 5 days  EMA for 10 days  EMA for 20 days  EMA for 50 days  \
# 0          38.231800        38.231800        38.231800        38.231800
# 1          36.831200        37.467836        37.831629        38.067024
# 2          34.887467        36.291866        37.180997        37.789885
# 3          33.924978        35.511527        36.687569        37.562831
# 4          33.626652        35.060340        36.339229        37.385073
# ...              ...              ...              ...              ...
# 2668      117.800705       117.531164       116.637103       119.704974
# 2669      117.493804       117.412770       116.660236       119.594191
# 2670      116.869202       117.086812       116.561166       119.438340
# 2671      117.999468       117.663755       116.913436       119.470562
# 2672      118.779646       118.150345       117.239776       119.504658
#
#          RSI_14      MACD  Signal_Line
# 0           NaN  0.000000     0.000000
# 1           NaN -0.335186    -0.067037
# 2           NaN -0.835686    -0.220767
# 3           NaN -1.138520    -0.404318
# 4           NaN -1.280644    -0.579583
# ...         ...       ...          ...
# 2668  44.652862  0.867627     0.726838
# 2669  54.070796  0.765449     0.734560
# 2670  52.416357  0.576159     0.702880
# 2671  56.451191  0.791432     0.720590
# 2672  55.885472  0.957455     0.767963
#
# [2673 rows x 17 columns]
#                   count          mean           std           min  \
# Open             2673.0  1.479633e+02  8.696828e+01  1.808000e+01
# High             2673.0  1.498468e+02  8.805465e+01  1.827000e+01
# Low              2673.0  1.460862e+02  8.591529e+01  1.755000e+01
# Close            2673.0  1.479917e+02  8.699929e+01  1.772900e+01
# Volume           2673.0  3.115405e+07  2.721709e+07  5.913066e+06
# MA for 5 days    2669.0  1.480981e+02  8.692966e+01  1.846140e+01
# MA for 10 days   2664.0  1.482359e+02  8.686269e+01  1.877955e+01
# MA for 20 days   2654.0  1.485193e+02  8.673551e+01  1.925918e+01
# MA for 50 days   2624.0  1.493997e+02  8.630554e+01  2.017572e+01
# EMA for 5 days   2673.0  1.479314e+02  8.694024e+01  1.846579e+01
# EMA for 10 days  2673.0  1.478571e+02  8.690014e+01  1.890858e+01
# EMA for 20 days  2673.0  1.477109e+02  8.681879e+01  1.968711e+01
# EMA for 50 days  2673.0  1.472468e+02  8.654123e+01  2.106646e+01
# RSI_14           2660.0  5.344210e+01  1.577691e+01  9.768073e+00
# MACD             2673.0  2.043057e-01  4.256432e+00 -2.904631e+01
# Signal_Line      2673.0  2.031565e-01  4.032827e+00 -2.706266e+01
#
#                           25%           50%           75%           max
# Open             7.780000e+01  1.422600e+02  1.913600e+02  3.816800e+02
# High             7.853000e+01  1.445600e+02  1.940300e+02  3.843300e+02
# Low              7.705000e+01  1.408700e+02  1.884700e+02  3.788100e+02
# Close            7.783000e+01  1.422800e+02  1.912900e+02  3.821800e+02
# Volume           1.618928e+07  2.313342e+07  3.599420e+07  5.735764e+08
# MA for 5 days    7.780600e+01  1.422620e+02  1.913780e+02  3.790300e+02
# MA for 10 days   7.777912e+01  1.418685e+02  1.917312e+02  3.786580e+02
# MA for 20 days   7.751544e+01  1.434165e+02  1.920813e+02  3.734220e+02
# MA for 50 days   7.745560e+01  1.471485e+02  1.906790e+02  3.637544e+02
# EMA for 5 days   7.757111e+01  1.420655e+02  1.913073e+02  3.782458e+02
# EMA for 10 days  7.745753e+01  1.418166e+02  1.908980e+02  3.763954e+02
# EMA for 20 days  7.711146e+01  1.424947e+02  1.903275e+02  3.728644e+02
# EMA for 50 days  7.669829e+01  1.454013e+02  1.891680e+02  3.629571e+02
# RSI_14           4.233863e+01  5.403817e+01  6.516629e+01  9.498106e+01
# MACD            -8.841952e-01  6.689780e-01  2.167294e+00  1.363001e+01
# Signal_Line     -8.958244e-01  6.345334e-01  1.986112e+00  1.163432e+01

# %%
data.dropna(inplace=True)
data.head(500)
# Out:
#            Date    Open   High     Low  Close     Volume  MA for 5 days  \
# 49   2012-07-30  23.995  24.04  23.030  23.15   29285900       26.29800
# 50   2012-07-31  23.370  23.37  21.610  21.71   56179400       24.95000
# 51   2012-08-01  21.500  21.58  20.840  20.88   44604400       23.25800
# 52   2012-08-02  20.770  20.84  19.820  20.04   56374500       21.89700
# 53   2012-08-03  20.360  22.16  19.900  21.09   80647000       21.37400
# ..          ...     ...    ...     ...    ...        ...            ...
# 544  2014-07-21  68.810  69.96  68.500  69.40   49431600       67.81096
# 545  2014-07-22  69.760  69.77  68.610  69.27   40301800       68.23196
# 546  2014-07-23  69.740  71.33  69.610  71.29   77435900       68.95796
# 547  2014-07-24  75.960  76.74  74.510  74.98  124006900       70.67198
# 548  2014-07-25  74.990  75.67  74.662  75.19   45823100       72.02600
#
#      MA for 10 days  MA for 20 days  MA for 50 days  EMA for 5 days  \
# 49         27.52000       29.237800       29.838636       25.546291
# 50         26.88200       28.784750       29.508200       24.267527
# 51         26.05900       28.268750       29.245200       23.138351
# 52         25.16300       27.697250       29.026000       22.105568
# 53         24.39600       27.165250       28.807800       21.767045
# ..              ...             ...             ...             ...
# 544        66.58973       66.626865       64.001716       68.007206
# 545        67.24073       66.821865       64.242316       68.428138
# 546        67.87273       67.100365       64.471516       69.382092
# 547        68.88348       67.477365       64.774516       71.248061
# 548        69.76848       67.880365       65.093716       72.562041
#
#      EMA for 10 days  EMA for 20 days  EMA for 50 days     RSI_14      MACD  \
# 49         27.046144        28.449746        30.538853  15.733114 -1.525536
# 50         26.075936        27.807865        30.192623  14.602446 -1.869091
# 51         25.131220        27.148068        29.827422  13.890909 -2.183168
# 52         24.205544        26.471110        29.443602  13.172414 -2.471369
# 53         23.639081        25.958623        29.116010  22.638623 -2.585243
# ..               ...              ...              ...        ...       ...
# 544        67.283914        66.478537        64.769416  56.251778  1.037495
# 545        67.645020        66.744391        64.945909  53.726471  1.134074
# 546        68.307744        67.177306        65.194697  64.538726  1.357958
# 547        69.520881        67.920420        65.578435  71.536342  1.812249
# 548        70.551630        68.612761        65.955359  75.534944  2.164275
#
#      Signal_Line
# 49     -0.894611
# 50     -1.089507
# 51     -1.308239
# 52     -1.540865
# 53     -1.749740
# ..           ...
# 544     0.876412
# 545     0.927944
# 546     1.013947
# 547     1.173608
# 548     1.371741
#
# [500 rows x 17 columns]

# %%
# updated Code

from sklearn.model_selection import train_test_split
import numpy as np

X = []
Y = []
window_size = 15

# Iterating through the dataset to create inputs and targets
for i in range(1, len(df) - window_size - 1, 1):
    first_close = df.iloc[i, 4]  # Normalize using "Close" price
    temp = []
    temp2 = []
    for j in range(window_size):
        # Normalize "Close" and include RSI_14 as a second feature
        normalized_close = (df.iloc[i + j, 4] - first_close) / first_close
        rsi_14 = df.iloc[i + j, -1]  # Assuming RSI_14 is the last column
        temp.append([normalized_close, rsi_14])  # Add both features as a pair
    temp2.append((df.iloc[i + window_size, 4] - first_close) / first_close)  # Use "Close" for target
    X.append(np.array(temp))  # Each sample has shape (100, 2)
    Y.append(np.array(temp2).reshape(1, 1))

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# Converting lists to numpy arrays
train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

# Reshaping the data for CNN models
train_X = train_X.reshape(train_X.shape[0], 1, 15, 2)  
test_X = test_X.reshape(test_X.shape[0], 1, 15, 2)

# Printing the number of training and testing samples
print(len(train_X))
print(len(test_X))
# Out:
# 2085
# 522

# %%
# Check if there are any NaN values

print(np.isnan(train_X).any(), np.isnan(train_Y).any())
print(np.isinf(train_X).any(), np.isinf(train_Y).any())
# Out:
# False False
# False False

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Create the model
model = tf.keras.Sequential()

# Enhanced CNN layers with BatchNormalization and LeakyReLU
model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                               input_shape=(None, 100, 1))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Flatten()))

# Enhanced LSTM layers (removed clip_norm parameter)
model.add(Bidirectional(LSTM(128, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Bidirectional(LSTM(64, return_sequences=False,
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Dense layers with regularization
model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# Optimizer with gradient clipping (clipnorm moved here)
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

model.compile(optimizer=optimizer,
             loss='mse',
             metrics=['mse', 'mae'])

# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )
]

# Train the model
history = model.fit(
    train_X, 
    train_Y,
    validation_data=(test_X, test_Y),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/100
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - loss: 0.7792 - mae: 0.5473 - mse: 0.4915 - val_loss: 0.2163 - val_mae: 0.0871 - val_mse: 0.0118 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3500 - mae: 0.3022 - mse: 0.1528 - val_loss: 0.1972 - val_mae: 0.0806 - val_mse: 0.0105 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2691 - mae: 0.2231 - mse: 0.0836 - val_loss: 0.1927 - val_mae: 0.0752 - val_mse: 0.0101 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2333 - mae: 0.1762 - mse: 0.0516 - val_loss: 0.1897 - val_mae: 0.0768 - val_mse: 0.0107 - learning_rate: 0.0010
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2190 - mae: 0.1565 - mse: 0.0409 - val_loss: 0.1831 - val_mae: 0.0648 - val_mse: 0.0080 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2051 - mae: 0.1365 - mse: 0.0311 - val_loss: 0.1804 - val_mae: 0.0699 - val_mse: 0.0096 - learning_rate: 0.0010
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1940 - mae: 0.1196 - mse: 0.0244 - val_loss: 0.1748 - val_mae: 0.0676 - val_mse: 0.0086 - learning_rate: 0.0010
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1841 - mae: 0.1072 - mse: 0.0191 - val_loss: 0.1688 - val_mae: 0.0602 - val_mse: 0.0075 - learning_rate: 0.0010
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1745 - mae: 0.0935 - mse: 0.0145 - val_loss: 0.1635 - val_mae: 0.0620 - val_mse: 0.0073 - learning_rate: 0.0010
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1673 - mae: 0.0848 - mse: 0.0123 - val_loss: 0.1586 - val_mae: 0.0624 - val_mse: 0.0077 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1609 - mae: 0.0827 - mse: 0.0112 - val_loss: 0.1527 - val_mae: 0.0596 - val_mse: 0.0070 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1555 - mae: 0.0806 - mse: 0.0110 - val_loss: 0.1469 - val_mae: 0.0583 - val_mse: 0.0065 - learning_rate: 0.0010
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1483 - mae: 0.0727 - mse: 0.0093 - val_loss: 0.1414 - val_mae: 0.0575 - val_mse: 0.0065 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1409 - mae: 0.0655 - mse: 0.0074 - val_loss: 0.1357 - val_mae: 0.0602 - val_mse: 0.0064 - learning_rate: 0.0010
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1346 - mae: 0.0621 - mse: 0.0066 - val_loss: 0.1302 - val_mae: 0.0590 - val_mse: 0.0065 - learning_rate: 0.0010
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1291 - mae: 0.0624 - mse: 0.0067 - val_loss: 0.1238 - val_mae: 0.0550 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1235 - mae: 0.0598 - mse: 0.0066 - val_loss: 0.1179 - val_mae: 0.0531 - val_mse: 0.0051 - learning_rate: 0.0010
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1171 - mae: 0.0570 - mse: 0.0057 - val_loss: 0.1124 - val_mae: 0.0512 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1111 - mae: 0.0532 - mse: 0.0051 - val_loss: 0.1078 - val_mae: 0.0543 - val_mse: 0.0058 - learning_rate: 0.0010
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1060 - mae: 0.0558 - mse: 0.0053 - val_loss: 0.1013 - val_mae: 0.0485 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0998 - mae: 0.0501 - mse: 0.0044 - val_loss: 0.0962 - val_mae: 0.0492 - val_mse: 0.0048 - learning_rate: 0.0010
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0945 - mae: 0.0501 - mse: 0.0043 - val_loss: 0.0917 - val_mae: 0.0517 - val_mse: 0.0053 - learning_rate: 0.0010
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0891 - mae: 0.0476 - mse: 0.0039 - val_loss: 0.0864 - val_mae: 0.0492 - val_mse: 0.0050 - learning_rate: 0.0010
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0840 - mae: 0.0456 - mse: 0.0037 - val_loss: 0.0817 - val_mae: 0.0492 - val_mse: 0.0050 - learning_rate: 0.0010
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0796 - mae: 0.0467 - mse: 0.0040 - val_loss: 0.0784 - val_mae: 0.0537 - val_mse: 0.0063 - learning_rate: 0.0010
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0743 - mae: 0.0425 - mse: 0.0033 - val_loss: 0.0720 - val_mae: 0.0496 - val_mse: 0.0044 - learning_rate: 0.0010
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0697 - mae: 0.0420 - mse: 0.0032 - val_loss: 0.0679 - val_mae: 0.0480 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0657 - mae: 0.0420 - mse: 0.0033 - val_loss: 0.0653 - val_mae: 0.0546 - val_mse: 0.0060 - learning_rate: 0.0010
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0619 - mae: 0.0437 - mse: 0.0035 - val_loss: 0.0596 - val_mae: 0.0467 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0576 - mae: 0.0412 - mse: 0.0031 - val_loss: 0.0565 - val_mae: 0.0473 - val_mse: 0.0048 - learning_rate: 0.0010
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0535 - mae: 0.0386 - mse: 0.0027 - val_loss: 0.0523 - val_mae: 0.0481 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0505 - mae: 0.0412 - mse: 0.0032 - val_loss: 0.0495 - val_mae: 0.0467 - val_mse: 0.0047 - learning_rate: 0.0010
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0468 - mae: 0.0388 - mse: 0.0028 - val_loss: 0.0465 - val_mae: 0.0552 - val_mse: 0.0049 - learning_rate: 0.0010
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0435 - mae: 0.0374 - mse: 0.0026 - val_loss: 0.0417 - val_mae: 0.0405 - val_mse: 0.0031 - learning_rate: 0.0010
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0403 - mae: 0.0371 - mse: 0.0024 - val_loss: 0.0387 - val_mae: 0.0388 - val_mse: 0.0029 - learning_rate: 0.0010
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0377 - mae: 0.0361 - mse: 0.0024 - val_loss: 0.0374 - val_mae: 0.0455 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0360 - mae: 0.0405 - mse: 0.0030 - val_loss: 0.0361 - val_mae: 0.0530 - val_mse: 0.0049 - learning_rate: 0.0010
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0330 - mae: 0.0356 - mse: 0.0024 - val_loss: 0.0354 - val_mae: 0.0582 - val_mse: 0.0066 - learning_rate: 0.0010
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0316 - mae: 0.0402 - mse: 0.0029 - val_loss: 0.0336 - val_mae: 0.0561 - val_mse: 0.0066 - learning_rate: 0.0010
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0289 - mae: 0.0364 - mse: 0.0025 - val_loss: 0.0288 - val_mae: 0.0474 - val_mse: 0.0041 - learning_rate: 0.0010
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0270 - mae: 0.0368 - mse: 0.0027 - val_loss: 0.0279 - val_mae: 0.0530 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0242 - mae: 0.0315 - mse: 0.0019 - val_loss: 0.0251 - val_mae: 0.0456 - val_mse: 0.0041 - learning_rate: 0.0010
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0230 - mae: 0.0354 - mse: 0.0024 - val_loss: 0.0224 - val_mae: 0.0413 - val_mse: 0.0029 - learning_rate: 0.0010
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0212 - mae: 0.0342 - mse: 0.0021 - val_loss: 0.0241 - val_mae: 0.0553 - val_mse: 0.0062 - learning_rate: 0.0010
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0201 - mae: 0.0351 - mse: 0.0025 - val_loss: 0.0211 - val_mae: 0.0506 - val_mse: 0.0045 - learning_rate: 0.0010
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0187 - mae: 0.0350 - mse: 0.0024 - val_loss: 0.0194 - val_mae: 0.0448 - val_mse: 0.0040 - learning_rate: 0.0010
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0173 - mae: 0.0333 - mse: 0.0021 - val_loss: 0.0195 - val_mae: 0.0490 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0162 - mae: 0.0328 - mse: 0.0022 - val_loss: 0.0175 - val_mae: 0.0464 - val_mse: 0.0043 - learning_rate: 0.0010
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0151 - mae: 0.0336 - mse: 0.0021 - val_loss: 0.0155 - val_mae: 0.0402 - val_mse: 0.0033 - learning_rate: 0.0010
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0141 - mae: 0.0323 - mse: 0.0021 - val_loss: 0.0150 - val_mae: 0.0433 - val_mse: 0.0037 - learning_rate: 0.0010
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0129 - mae: 0.0314 - mse: 0.0019 - val_loss: 0.0144 - val_mae: 0.0451 - val_mse: 0.0038 - learning_rate: 0.0010
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0128 - mae: 0.0340 - mse: 0.0023 - val_loss: 0.0174 - val_mae: 0.0602 - val_mse: 0.0076 - learning_rate: 0.0010
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0124 - mae: 0.0348 - mse: 0.0025 - val_loss: 0.0133 - val_mae: 0.0448 - val_mse: 0.0039 - learning_rate: 0.0010
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0114 - mae: 0.0332 - mse: 0.0023 - val_loss: 0.0116 - val_mae: 0.0392 - val_mse: 0.0031 - learning_rate: 0.0010
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0105 - mae: 0.0336 - mse: 0.0022 - val_loss: 0.0120 - val_mae: 0.0501 - val_mse: 0.0038 - learning_rate: 0.0010
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0098 - mae: 0.0301 - mse: 0.0017 - val_loss: 0.0101 - val_mae: 0.0381 - val_mse: 0.0026 - learning_rate: 0.0010
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0091 - mae: 0.0310 - mse: 0.0018 - val_loss: 0.0109 - val_mae: 0.0460 - val_mse: 0.0041 - learning_rate: 0.0010
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0088 - mae: 0.0315 - mse: 0.0020 - val_loss: 0.0103 - val_mae: 0.0424 - val_mse: 0.0036 - learning_rate: 0.0010
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0086 - mae: 0.0311 - mse: 0.0021 - val_loss: 0.0106 - val_mae: 0.0492 - val_mse: 0.0045 - learning_rate: 0.0010
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - mae: 0.0316 - mse: 0.0020 - val_loss: 0.0090 - val_mae: 0.0441 - val_mse: 0.0034 - learning_rate: 0.0010
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0074 - mae: 0.0306 - mse: 0.0018 - val_loss: 0.0080 - val_mae: 0.0396 - val_mse: 0.0028 - learning_rate: 0.0010
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0077 - mae: 0.0353 - mse: 0.0024 - val_loss: 0.0088 - val_mae: 0.0434 - val_mse: 0.0037 - learning_rate: 0.0010
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0068 - mae: 0.0302 - mse: 0.0017 - val_loss: 0.0110 - val_mae: 0.0570 - val_mse: 0.0061 - learning_rate: 0.0010
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0070 - mae: 0.0320 - mse: 0.0021 - val_loss: 0.0076 - val_mae: 0.0427 - val_mse: 0.0030 - learning_rate: 0.0010
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0064 - mae: 0.0300 - mse: 0.0018 - val_loss: 0.0118 - val_mae: 0.0610 - val_mse: 0.0074 - learning_rate: 0.0010
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0064 - mae: 0.0314 - mse: 0.0019 - val_loss: 0.0086 - val_mae: 0.0468 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0063 - mae: 0.0315 - mse: 0.0020 - val_loss: 0.0101 - val_mae: 0.0540 - val_mse: 0.0060 - learning_rate: 0.0010
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0058 - mae: 0.0308 - mse: 0.0018 - val_loss: 0.0066 - val_mae: 0.0403 - val_mse: 0.0029 - learning_rate: 0.0010
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0052 - mae: 0.0290 - mse: 0.0017 - val_loss: 0.0059 - val_mae: 0.0371 - val_mse: 0.0024 - learning_rate: 0.0010
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0052 - mae: 0.0298 - mse: 0.0018 - val_loss: 0.0069 - val_mae: 0.0412 - val_mse: 0.0035 - learning_rate: 0.0010
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0057 - mae: 0.0328 - mse: 0.0022 - val_loss: 0.0072 - val_mae: 0.0430 - val_mse: 0.0036 - learning_rate: 0.0010
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0054 - mae: 0.0313 - mse: 0.0019 - val_loss: 0.0100 - val_mae: 0.0578 - val_mse: 0.0068 - learning_rate: 0.0010
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0054 - mae: 0.0321 - mse: 0.0021 - val_loss: 0.0114 - val_mae: 0.0702 - val_mse: 0.0084 - learning_rate: 0.0010
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0056 - mae: 0.0343 - mse: 0.0023 - val_loss: 0.0081 - val_mae: 0.0543 - val_mse: 0.0048 - learning_rate: 0.0010
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0050 - mae: 0.0308 - mse: 0.0020 - val_loss: 0.0049 - val_mae: 0.0346 - val_mse: 0.0023 - learning_rate: 2.0000e-04
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mae: 0.0279 - mse: 0.0016 - val_loss: 0.0058 - val_mae: 0.0411 - val_mse: 0.0034 - learning_rate: 2.0000e-04
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0038 - mae: 0.0275 - mse: 0.0014 - val_loss: 0.0045 - val_mae: 0.0342 - val_mse: 0.0023 - learning_rate: 2.0000e-04
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - mae: 0.0277 - mse: 0.0015 - val_loss: 0.0050 - val_mae: 0.0393 - val_mse: 0.0028 - learning_rate: 2.0000e-04
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0036 - mae: 0.0271 - mse: 0.0015 - val_loss: 0.0048 - val_mae: 0.0378 - val_mse: 0.0027 - learning_rate: 2.0000e-04
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0037 - mae: 0.0293 - mse: 0.0017 - val_loss: 0.0045 - val_mae: 0.0357 - val_mse: 0.0025 - learning_rate: 2.0000e-04
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033 - mae: 0.0259 - mse: 0.0013 - val_loss: 0.0041 - val_mae: 0.0351 - val_mse: 0.0022 - learning_rate: 2.0000e-04
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0036 - mae: 0.0284 - mse: 0.0016 - val_loss: 0.0041 - val_mae: 0.0349 - val_mse: 0.0022 - learning_rate: 2.0000e-04
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0038 - mae: 0.0290 - mse: 0.0018 - val_loss: 0.0040 - val_mae: 0.0336 - val_mse: 0.0020 - learning_rate: 2.0000e-04
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0036 - mae: 0.0291 - mse: 0.0016 - val_loss: 0.0037 - val_mae: 0.0320 - val_mse: 0.0018 - learning_rate: 2.0000e-04
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033 - mae: 0.0277 - mse: 0.0014 - val_loss: 0.0040 - val_mae: 0.0361 - val_mse: 0.0022 - learning_rate: 2.0000e-04
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0034 - mae: 0.0290 - mse: 0.0016 - val_loss: 0.0038 - val_mae: 0.0326 - val_mse: 0.0020 - learning_rate: 2.0000e-04
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0031 - mae: 0.0261 - mse: 0.0014 - val_loss: 0.0042 - val_mae: 0.0345 - val_mse: 0.0025 - learning_rate: 2.0000e-04
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0272 - mse: 0.0014 - val_loss: 0.0035 - val_mae: 0.0319 - val_mse: 0.0019 - learning_rate: 2.0000e-04
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - mae: 0.0275 - mse: 0.0015 - val_loss: 0.0036 - val_mae: 0.0331 - val_mse: 0.0020 - learning_rate: 2.0000e-04
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mae: 0.0269 - mse: 0.0014 - val_loss: 0.0038 - val_mae: 0.0342 - val_mse: 0.0023 - learning_rate: 2.0000e-04
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mae: 0.0266 - mse: 0.0014 - val_loss: 0.0030 - val_mae: 0.0289 - val_mse: 0.0015 - learning_rate: 2.0000e-04
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0279 - mse: 0.0015 - val_loss: 0.0035 - val_mae: 0.0330 - val_mse: 0.0020 - learning_rate: 2.0000e-04
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0031 - mae: 0.0275 - mse: 0.0016 - val_loss: 0.0031 - val_mae: 0.0299 - val_mse: 0.0016 - learning_rate: 2.0000e-04
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030 - mae: 0.0282 - mse: 0.0015 - val_loss: 0.0032 - val_mae: 0.0309 - val_mse: 0.0018 - learning_rate: 2.0000e-04
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0028 - mae: 0.0262 - mse: 0.0014 - val_loss: 0.0030 - val_mae: 0.0297 - val_mse: 0.0016 - learning_rate: 2.0000e-04
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mae: 0.0270 - mse: 0.0015 - val_loss: 0.0029 - val_mae: 0.0297 - val_mse: 0.0016 - learning_rate: 2.0000e-04
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - mae: 0.0281 - mse: 0.0016 - val_loss: 0.0030 - val_mae: 0.0289 - val_mse: 0.0016 - learning_rate: 2.0000e-04
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - mae: 0.0263 - mse: 0.0013 - val_loss: 0.0040 - val_mae: 0.0362 - val_mse: 0.0027 - learning_rate: 2.0000e-04
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - mae: 0.0289 - mse: 0.0016 - val_loss: 0.0034 - val_mae: 0.0336 - val_mse: 0.0021 - learning_rate: 2.0000e-04
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - mae: 0.0268 - mse: 0.0014 - val_loss: 0.0031 - val_mae: 0.0305 - val_mse: 0.0018 - learning_rate: 2.0000e-04

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

print("Training Loss:", history.history.get('loss', []))
print("Validation Loss:", history.history.get('val_loss', []))
# Out:
# Training Loss: [0.5956831574440002, 0.32355982065200806, 0.26169896125793457, 0.22943836450576782, 0.21327979862689972, 0.20337575674057007, 0.1919790804386139, 0.18160480260849, 0.17322708666324615, 0.16589534282684326, 0.1590884029865265, 0.15366579592227936, 0.1469132900238037, 0.1398763656616211, 0.13331836462020874, 0.12772969901561737, 0.1213117241859436, 0.1156463697552681, 0.1099662259221077, 0.10469463467597961, 0.09867065399885178, 0.09333840012550354, 0.087885782122612, 0.08274122327566147, 0.07829784601926804, 0.07305386662483215, 0.06889808923006058, 0.06474656611680984, 0.06062302738428116, 0.056392066180706024, 0.05278034508228302, 0.04941903054714203, 0.046042732894420624, 0.042665474116802216, 0.039884284138679504, 0.03707977756857872, 0.03540926054120064, 0.03259732574224472, 0.030994951725006104, 0.028253087773919106, 0.02635147050023079, 0.023980259895324707, 0.022480346262454987, 0.02074168249964714, 0.01960497722029686, 0.018157288432121277, 0.016990317031741142, 0.015901394188404083, 0.014772743918001652, 0.013776350766420364, 0.013034638948738575, 0.01251163613051176, 0.012027602642774582, 0.010974782519042492, 0.010409845970571041, 0.009781391359865665, 0.008930651471018791, 0.008836096152663231, 0.00841065589338541, 0.007787261623889208, 0.0072371093556284904, 0.00738676218315959, 0.006837052293121815, 0.006932266987860203, 0.006456146948039532, 0.006260349415242672, 0.006277174688875675, 0.005728861782699823, 0.0053337193094193935, 0.005239511374384165, 0.005735450889915228, 0.005510765593498945, 0.00534206535667181, 0.005575885064899921, 0.004653649870306253, 0.004118365701287985, 0.003866539103910327, 0.003663616254925728, 0.003618905320763588, 0.00362188252620399, 0.0033669662661850452, 0.0035099980887025595, 0.003698933171108365, 0.003574990201741457, 0.0032894015312194824, 0.0033773977775126696, 0.003220453392714262, 0.003112848848104477, 0.003045839024707675, 0.003083170158788562, 0.003007639665156603, 0.003120557637885213, 0.0030102382879704237, 0.003089041216298938, 0.002819979563355446, 0.0028240280225872993, 0.0028665107674896717, 0.002797891851514578, 0.0029133390635252, 0.0028299300465732813]
# Validation Loss: [0.2163190096616745, 0.19718725979328156, 0.19268445670604706, 0.18966029584407806, 0.18312880396842957, 0.1803928166627884, 0.17475953698158264, 0.16877613961696625, 0.16351044178009033, 0.15863120555877686, 0.1526775360107422, 0.1469145268201828, 0.1414145529270172, 0.13573940098285675, 0.13018015027046204, 0.12378698587417603, 0.11785270273685455, 0.11244183033704758, 0.10775285214185715, 0.10125026851892471, 0.09622744470834732, 0.09166648983955383, 0.086420938372612, 0.08167459070682526, 0.0783662274479866, 0.07202716916799545, 0.06793594360351562, 0.06532138586044312, 0.05962308868765831, 0.056490834802389145, 0.05232856795191765, 0.04949454590678215, 0.04651037976145744, 0.04170200228691101, 0.03874357417225838, 0.03744851425290108, 0.036137599498033524, 0.035410258919000626, 0.033635955303907394, 0.028842927888035774, 0.027942484244704247, 0.025067424401640892, 0.02235332503914833, 0.02413141541182995, 0.021063625812530518, 0.019434751942753792, 0.01945643499493599, 0.017499808222055435, 0.01549591589719057, 0.01500128023326397, 0.014439793303608894, 0.017397982999682426, 0.013296647928655148, 0.011559955775737762, 0.011991728097200394, 0.010082313790917397, 0.010872316546738148, 0.01032132375985384, 0.010611158795654774, 0.009026889689266682, 0.007990933954715729, 0.008842788636684418, 0.010985040105879307, 0.007648527156561613, 0.01179503183811903, 0.008560920134186745, 0.010133097879588604, 0.006555730942636728, 0.00588903808966279, 0.006853452883660793, 0.007182879373431206, 0.010045075789093971, 0.011442328803241253, 0.008083214052021503, 0.004894359037280083, 0.005764647386968136, 0.004520353861153126, 0.004952459596097469, 0.004782258067280054, 0.004500153474509716, 0.004085969179868698, 0.004072014708071947, 0.004046444781124592, 0.003713815938681364, 0.004021141212433577, 0.0037527456879615784, 0.004164007026702166, 0.003529604524374008, 0.003648752812296152, 0.0038421975914388895, 0.003045948687940836, 0.003520058933645487, 0.0030655618757009506, 0.0032313994597643614, 0.0030224728398025036, 0.002934727817773819, 0.002996232593432069, 0.004046246875077486, 0.0034346571192145348, 0.003098201472312212]

# %%
# mse
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# mae
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0255 - mse: 0.0011
# [0.002934727817773819, 0.0015604182844981551, 0.02969677932560444]

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.844661
# R2 Score: 0.844661
# Max Error: 0.244590

# %%
# make predictions
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp


# # Get predictions from the model
# predicted = model.predict(test_X)

# # Reshape the actual test labels and predictions to ensure proper shape
# test_label = test_Y.reshape(-1,1)
# predicted = np.array(predicted[:,0]).reshape(-1,1)

# # Get the length of training data
# len_t = len(train_X)

# # Inverse transform the predictions and actual values
# # This loop is denormalizing/inverse scaling the predictions and actual values
# for j in range(len_t, len_t + len(test_X)):
#     temp = data.iloc[j,3]  # Getting the original scale factor
#     # Inverse transform actual values
#     test_label[j - len_t] = test_label[j - len_t] * temp + temp
#     # Inverse transform predictions
#     predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Create figure and axis with specified size
    plt.figure(figsize=(15, 7))
    
    # Plot actual prices
    plt.plot(test_label, label='Actual Price', color='green')
    
    # Plot predicted prices
    plt.plot(predicted, label='Predicted Price', color='red')
    
    # Customize the plot
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add margins for better visibility
    plt.margins(x=0.02)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Show plot
    plt.show()

def plot_predictions_with_dates(test_label, predicted, dates, title="Stock Price Prediction"):
    plt.figure(figsize=(15, 6))
    
    # Plot with dates
    plt.plot(dates, test_label, label='Actual Price', color='blue', linewidth=2)
    plt.plot(dates, predicted, label='Predicted Price', color='red', linestyle='--', linewidth=2)
    
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Format date axis
    plt.gcf().autofmt_xdate()  # Angle and align the tick labels
    
    plt.tight_layout()
    plt.show()

# %%
from scipy.signal import savgol_filter

def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Apply smoothing to both lines
    window_length = 5  # Must be odd; adjust this value to control smoothing amount
    polyorder = 1
    
    # Smooth both actual and predicted values
    test_label_smooth = savgol_filter(test_label.flatten(), window_length, polyorder)
    predicted_smooth = savgol_filter(predicted.flatten(), window_length, polyorder)
    
    plt.figure(figsize=(15, 6))
    
    # Plot smoothed lines
    plt.plot(test_label_smooth, label='Actual Price', color='red')
    plt.plot(predicted_smooth, label='Predicted Price', color='blue')
    
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_predictions(test_label, predicted, "Stock Price Prediction")

# %%
# Performance Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Calculate performance metrics
mse = mean_squared_error(test_label, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_label, predicted)
mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100

# Print performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Squared Error (MSE): 87.66383224629644
# Root Mean Squared Error (RMSE): 9.362896573512732
# Mean Absolute Error (MAE): 7.082369248686042
# Mean Absolute Percentage Error (MAPE): 3.08%

# %%
# Save the trained model
model.save('improved_model.h5')  # Saves the entire model (architecture, weights, and optimizer state)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
