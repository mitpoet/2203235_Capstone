# %%
import numpy as np # linear algebra
import pandas as pd 
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('./meta.csv')
data.head()
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Reset index
data.reset_index(drop=True, inplace=True)

# Select numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Fill NaN values in numeric columns with the mean of those columns
data[numeric_data.columns] = data[numeric_data.columns].fillna(numeric_data.mean())

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Calculate moving average
ma_day = [5, 10, 20, 50]  # Common short-term and long-term windows
for ma in ma_day:
    column_name = f"MA for {ma} days"
    data[column_name] = data['Close'].rolling(window=ma).mean()

# Calculate Exponential moving average
for ma in ma_day:
    column_name = f"EMA for {ma} days"
    data[column_name] = data['Close'].ewm(span=ma, adjust=False).mean()

# Volatility (Standard Deviation): Capture price fluctuations:
# for ma in ma_day:
#     column_name = f"Volatility_{ma}d"
#     data[column_name] = data['Close'].rolling(window=ma).std()

# Calculate RSI
def compute_RSI(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data['RSI_14'] = compute_RSI(data)

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date    Open     High       Low     Close     Volume  \
# 0     2012-05-18   42.05   45.000   38.0000   38.2318  573576400
# 1     2012-05-21   36.53   36.660   33.0000   34.0300  168192700
# 2     2012-05-22   32.61   33.590   30.9400   31.0000  101786600
# 3     2012-05-23   31.37   32.500   31.3600   32.0000   73600000
# 4     2012-05-24   32.95   33.210   31.7700   33.0300   50237200
# ...          ...     ...      ...       ...       ...        ...
# 2668  2022-12-23  116.03  118.175  115.5350  118.0400   17796625
# 2669  2022-12-27  117.93  118.600  116.0501  116.8800   21392311
# 2670  2022-12-28  116.25  118.150  115.5100  115.6200   19612473
# 2671  2022-12-29  116.40  121.030  115.7700  120.2600   22366192
# 2672  2022-12-30  118.16  120.420  117.7400  120.3400   19583825
#
#       MA for 5 days  MA for 10 days  MA for 20 days  MA for 50 days  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4          33.65836             NaN             NaN             NaN
# ...             ...             ...             ...             ...
# 2668      117.29800         117.852         117.025        114.2838
# 2669      117.77800         118.069         117.430        114.0862
# 2670      117.48400         117.616         117.738        113.7178
# 2671      117.58400         117.483         117.846        113.4670
# 2672      118.22800         117.902         117.841        113.2092
#
#       EMA for 5 days  EMA for 10 days  EMA for 20 days  EMA for 50 days  \
# 0          38.231800        38.231800        38.231800        38.231800
# 1          36.831200        37.467836        37.831629        38.067024
# 2          34.887467        36.291866        37.180997        37.789885
# 3          33.924978        35.511527        36.687569        37.562831
# 4          33.626652        35.060340        36.339229        37.385073
# ...              ...              ...              ...              ...
# 2668      117.800705       117.531164       116.637103       119.704974
# 2669      117.493804       117.412770       116.660236       119.594191
# 2670      116.869202       117.086812       116.561166       119.438340
# 2671      117.999468       117.663755       116.913436       119.470562
# 2672      118.779646       118.150345       117.239776       119.504658
#
#          RSI_14      MACD
# 0           NaN  0.000000
# 1           NaN -0.335186
# 2           NaN -0.835686
# 3           NaN -1.138520
# 4           NaN -1.280644
# ...         ...       ...
# 2668  44.652862  0.867627
# 2669  54.070796  0.765449
# 2670  52.416357  0.576159
# 2671  56.451191  0.791432
# 2672  55.885472  0.957455
#
# [2673 rows x 16 columns]
#                   count          mean           std           min  \
# Open             2673.0  1.479633e+02  8.696828e+01  1.808000e+01
# High             2673.0  1.498468e+02  8.805465e+01  1.827000e+01
# Low              2673.0  1.460862e+02  8.591529e+01  1.755000e+01
# Close            2673.0  1.479917e+02  8.699929e+01  1.772900e+01
# Volume           2673.0  3.115405e+07  2.721709e+07  5.913066e+06
# MA for 5 days    2669.0  1.480981e+02  8.692966e+01  1.846140e+01
# MA for 10 days   2664.0  1.482359e+02  8.686269e+01  1.877955e+01
# MA for 20 days   2654.0  1.485193e+02  8.673551e+01  1.925918e+01
# MA for 50 days   2624.0  1.493997e+02  8.630554e+01  2.017572e+01
# EMA for 5 days   2673.0  1.479314e+02  8.694024e+01  1.846579e+01
# EMA for 10 days  2673.0  1.478571e+02  8.690014e+01  1.890858e+01
# EMA for 20 days  2673.0  1.477109e+02  8.681879e+01  1.968711e+01
# EMA for 50 days  2673.0  1.472468e+02  8.654123e+01  2.106646e+01
# RSI_14           2660.0  5.344210e+01  1.577691e+01  9.768073e+00
# MACD             2673.0  2.043057e-01  4.256432e+00 -2.904631e+01
#
#                           25%           50%           75%           max
# Open             7.780000e+01  1.422600e+02  1.913600e+02  3.816800e+02
# High             7.853000e+01  1.445600e+02  1.940300e+02  3.843300e+02
# Low              7.705000e+01  1.408700e+02  1.884700e+02  3.788100e+02
# Close            7.783000e+01  1.422800e+02  1.912900e+02  3.821800e+02
# Volume           1.618928e+07  2.313342e+07  3.599420e+07  5.735764e+08
# MA for 5 days    7.780600e+01  1.422620e+02  1.913780e+02  3.790300e+02
# MA for 10 days   7.777912e+01  1.418685e+02  1.917312e+02  3.786580e+02
# MA for 20 days   7.751544e+01  1.434165e+02  1.920813e+02  3.734220e+02
# MA for 50 days   7.745560e+01  1.471485e+02  1.906790e+02  3.637544e+02
# EMA for 5 days   7.757111e+01  1.420655e+02  1.913073e+02  3.782458e+02
# EMA for 10 days  7.745753e+01  1.418166e+02  1.908980e+02  3.763954e+02
# EMA for 20 days  7.711146e+01  1.424947e+02  1.903275e+02  3.728644e+02
# EMA for 50 days  7.669829e+01  1.454013e+02  1.891680e+02  3.629571e+02
# RSI_14           4.233863e+01  5.403817e+01  6.516629e+01  9.498106e+01
# MACD            -8.841952e-01  6.689780e-01  2.167294e+00  1.363001e+01

# %%
data.dropna(inplace=True)
data.head(500)
# Out:
#            Date    Open   High     Low  Close     Volume  MA for 5 days  \
# 49   2012-07-30  23.995  24.04  23.030  23.15   29285900       26.29800
# 50   2012-07-31  23.370  23.37  21.610  21.71   56179400       24.95000
# 51   2012-08-01  21.500  21.58  20.840  20.88   44604400       23.25800
# 52   2012-08-02  20.770  20.84  19.820  20.04   56374500       21.89700
# 53   2012-08-03  20.360  22.16  19.900  21.09   80647000       21.37400
# ..          ...     ...    ...     ...    ...        ...            ...
# 544  2014-07-21  68.810  69.96  68.500  69.40   49431600       67.81096
# 545  2014-07-22  69.760  69.77  68.610  69.27   40301800       68.23196
# 546  2014-07-23  69.740  71.33  69.610  71.29   77435900       68.95796
# 547  2014-07-24  75.960  76.74  74.510  74.98  124006900       70.67198
# 548  2014-07-25  74.990  75.67  74.662  75.19   45823100       72.02600
#
#      MA for 10 days  MA for 20 days  MA for 50 days  EMA for 5 days  \
# 49         27.52000       29.237800       29.838636       25.546291
# 50         26.88200       28.784750       29.508200       24.267527
# 51         26.05900       28.268750       29.245200       23.138351
# 52         25.16300       27.697250       29.026000       22.105568
# 53         24.39600       27.165250       28.807800       21.767045
# ..              ...             ...             ...             ...
# 544        66.58973       66.626865       64.001716       68.007206
# 545        67.24073       66.821865       64.242316       68.428138
# 546        67.87273       67.100365       64.471516       69.382092
# 547        68.88348       67.477365       64.774516       71.248061
# 548        69.76848       67.880365       65.093716       72.562041
#
#      EMA for 10 days  EMA for 20 days  EMA for 50 days     RSI_14      MACD
# 49         27.046144        28.449746        30.538853  15.733114 -1.525536
# 50         26.075936        27.807865        30.192623  14.602446 -1.869091
# 51         25.131220        27.148068        29.827422  13.890909 -2.183168
# 52         24.205544        26.471110        29.443602  13.172414 -2.471369
# 53         23.639081        25.958623        29.116010  22.638623 -2.585243
# ..               ...              ...              ...        ...       ...
# 544        67.283914        66.478537        64.769416  56.251778  1.037495
# 545        67.645020        66.744391        64.945909  53.726471  1.134074
# 546        68.307744        67.177306        65.194697  64.538726  1.357958
# 547        69.520881        67.920420        65.578435  71.536342  1.812249
# 548        70.551630        68.612761        65.955359  75.534944  2.164275
#
# [500 rows x 16 columns]

# %%
# updated Code

feature_columns = [
    'Close',          # Most important feature (direct price information)
    'Low',            # Important price-related feature
    'High',           # Important price-related feature
    'Open',           # Important price-related feature
    'EMA for 5 days', # Short-term trend indicator
    'MA for 5 days',  # Short-term trend indicator
    'RSI_14'          # Momentum indicator
]

from sklearn.model_selection import train_test_split
import numpy as np

X = []
Y = []
window_size = 15

# Iterating through the dataset to create inputs and targets
# for i in range(1, len(df) - window_size - 1, 1):
#     first_close = df.iloc[i, 4]  # Normalize using "Close" price
#     temp = []
#     temp2 = []
#     for j in range(window_size):
#         # Normalize "Close" and include RSI_14 as a second feature
#         normalized_close = (df.iloc[i + j, 4] - first_close) / first_close
#         rsi_14 = df.iloc[i + j, -1]  # Assuming RSI_14 is the last column
#         temp.append([normalized_close, rsi_14])  # Add both features as a pair
#     temp2.append((df.iloc[i + window_size, 4] - first_close) / first_close)  # Use "Close" for target
#     X.append(np.array(temp))  # Each sample has shape (100, 2)
#     Y.append(np.array(temp2).reshape(1, 1))

# Iterating through the dataset to create inputs and targets
for i in range(1, len(df) - window_size - 1, 1):
    first_close = df.iloc[i, df.columns.get_loc('Close')]  # Normalize using "Close" price
    temp = []
    temp2 = []
    
    for j in range(window_size):
        # Normalize each feature in the feature_columns list
        normalized_features = []
        for feature in feature_columns:
            if feature == 'Close':
                # Normalize "Close" relative to the first_close
                normalized_value = (df.iloc[i + j, df.columns.get_loc(feature)] - first_close) / first_close
            else:
                # For other features, normalize them directly (or use their raw values if normalization isn't required)
                normalized_value = df.iloc[i + j, df.columns.get_loc(feature)]
            normalized_features.append(normalized_value)
        
        # Append the normalized features for this time step
        temp.append(normalized_features)
    
    # Calculate the target (normalized change in "Close" price)
    target = (df.iloc[i + window_size, df.columns.get_loc('Close')] - first_close) / first_close
    temp2.append(target)
    
    # Append the input and target to X and Y
    X.append(np.array(temp))  # Each sample has shape (window_size, len(feature_columns))
    Y.append(np.array(temp2).reshape(1, 1))

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# Converting lists to numpy arrays
train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

# Verify the shape of train_X
print("Shape of train_X before reshaping:", train_X.shape)

# Reshaping the data for CNN models
# Assuming train_X has shape (num_samples, window_size, num_features)
train_X = train_X.reshape(train_X.shape[0], 1, train_X.shape[1], train_X.shape[2])  
test_X = test_X.reshape(test_X.shape[0], 1, test_X.shape[1], test_X.shape[2])

# Printing the number of training and testing samples
print("Shape of train_X after reshaping:", train_X.shape)
print("Shape of test_X after reshaping:", test_X.shape)
print("Number of training samples:", len(train_X))
print("Number of testing samples:", len(test_X))
# Out:
# Shape of train_X before reshaping: (2085, 15, 7)
# Shape of train_X after reshaping: (2085, 1, 15, 7)
# Shape of test_X after reshaping: (522, 1, 15, 7)
# Number of training samples: 2085
# Number of testing samples: 522

# %%
# Check if there are any NaN values

print(np.isnan(train_X).any(), np.isnan(train_Y).any())
print(np.isinf(train_X).any(), np.isinf(train_Y).any())
# Out:
# False False
# False False

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Create the model
# model = tf.keras.Sequential()

# # Enhanced CNN layers with BatchNormalization and LeakyReLU
# model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                                input_shape=(None, 100, 1))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Flatten()))

# # Enhanced LSTM layers (removed clip_norm parameter)
# model.add(Bidirectional(LSTM(128, return_sequences=True, 
#                             kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                             recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(BatchNormalization())
# model.add(Dropout(0.4))

# model.add(Bidirectional(LSTM(64, return_sequences=False,
#                             kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                             recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(BatchNormalization())
# model.add(Dropout(0.4))

# # Dense layers with regularization
# model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
# model.add(BatchNormalization())
# model.add(LeakyReLU(alpha=0.1))
# model.add(Dropout(0.2))

# model.add(Dense(1, activation='linear'))

# # Optimizer with gradient clipping (clipnorm moved here)
# optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

# model.compile(optimizer=optimizer,
#              loss='mse',
#              metrics=['mse', 'mae'])

# # Define callbacks
# callbacks = [
#     EarlyStopping(
#         monitor='val_loss',
#         patience=10,
#         restore_best_weights=True
#     ),
#     ReduceLROnPlateau(
#         monitor='val_loss',
#         factor=0.2,
#         patience=5,
#         min_lr=1e-6
#     )
# ]

# # Train the model
# history = model.fit(
#     train_X, 
#     train_Y,
#     validation_data=(test_X, test_Y),
#     epochs=100,
#     batch_size=32,
#     callbacks=callbacks,
#     verbose=1,
#     shuffle=True
# )

# Adding an Attention Layer
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.nn.tanh(tf.matmul(x, self.W) + self.b)
        at = tf.nn.softmax(et, axis=1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

# Create the model
model = tf.keras.Sequential()

# Enhanced CNN layers with BatchNormalization and LeakyReLU
model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                               input_shape=(None, 100, 1))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Flatten()))

# Enhanced LSTM layers (removed clip_norm parameter)
model.add(Bidirectional(LSTM(128, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(64, return_sequences=True,  # Set return_sequences=True for Attention
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Add Attention Layer here
model.add(AttentionLayer())

# Dense layers with regularization
model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# Optimizer with gradient clipping (clipnorm moved here)
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

model.compile(optimizer=optimizer,
             loss='mse',
             metrics=['mse', 'mae'])

# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )
]

# Train the model
history = model.fit(
    train_X, 
    train_Y,
    validation_data=(test_X, test_Y),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/100
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - loss: 1.1168 - mae: 0.7115 - mse: 0.8272 - val_loss: 0.2814 - val_mae: 0.2547 - val_mse: 0.0741 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4726 - mae: 0.4140 - mse: 0.2730 - val_loss: 0.2453 - val_mae: 0.2160 - val_mse: 0.0552 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3771 - mae: 0.3427 - mse: 0.1877 - val_loss: 0.2065 - val_mae: 0.1030 - val_mse: 0.0190 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3295 - mae: 0.3022 - mse: 0.1425 - val_loss: 0.2012 - val_mae: 0.0954 - val_mse: 0.0159 - learning_rate: 0.0010
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2822 - mae: 0.2447 - mse: 0.0976 - val_loss: 0.1964 - val_mae: 0.0841 - val_mse: 0.0138 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2568 - mae: 0.2137 - mse: 0.0749 - val_loss: 0.1921 - val_mae: 0.0794 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2313 - mae: 0.1823 - mse: 0.0524 - val_loss: 0.1892 - val_mae: 0.0792 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2175 - mae: 0.1618 - mse: 0.0420 - val_loss: 0.1873 - val_mae: 0.0897 - val_mse: 0.0145 - learning_rate: 0.0010
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2050 - mae: 0.1436 - mse: 0.0331 - val_loss: 0.1819 - val_mae: 0.0813 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1942 - mae: 0.1262 - mse: 0.0260 - val_loss: 0.1776 - val_mae: 0.0798 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1858 - mae: 0.1134 - mse: 0.0214 - val_loss: 0.1735 - val_mae: 0.0797 - val_mse: 0.0121 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1775 - mae: 0.1006 - mse: 0.0172 - val_loss: 0.1714 - val_mae: 0.0915 - val_mse: 0.0143 - learning_rate: 0.0010
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1720 - mae: 0.0980 - mse: 0.0159 - val_loss: 0.1638 - val_mae: 0.0745 - val_mse: 0.0110 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1650 - mae: 0.0866 - mse: 0.0133 - val_loss: 0.1608 - val_mae: 0.0815 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1594 - mae: 0.0840 - mse: 0.0120 - val_loss: 0.1542 - val_mae: 0.0716 - val_mse: 0.0102 - learning_rate: 0.0010
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1525 - mae: 0.0757 - mse: 0.0097 - val_loss: 0.1503 - val_mae: 0.0752 - val_mse: 0.0109 - learning_rate: 0.0010
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1476 - mae: 0.0724 - mse: 0.0093 - val_loss: 0.1440 - val_mae: 0.0678 - val_mse: 0.0092 - learning_rate: 0.0010
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1413 - mae: 0.0672 - mse: 0.0077 - val_loss: 0.1393 - val_mae: 0.0677 - val_mse: 0.0091 - learning_rate: 0.0010
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1355 - mae: 0.0604 - mse: 0.0065 - val_loss: 0.1354 - val_mae: 0.0717 - val_mse: 0.0099 - learning_rate: 0.0010
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1306 - mae: 0.0584 - mse: 0.0062 - val_loss: 0.1289 - val_mae: 0.0629 - val_mse: 0.0081 - learning_rate: 0.0010
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1255 - mae: 0.0559 - mse: 0.0058 - val_loss: 0.1235 - val_mae: 0.0595 - val_mse: 0.0074 - learning_rate: 0.0010
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1202 - mae: 0.0533 - mse: 0.0051 - val_loss: 0.1203 - val_mae: 0.0672 - val_mse: 0.0088 - learning_rate: 0.0010
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1157 - mae: 0.0533 - mse: 0.0053 - val_loss: 0.1135 - val_mae: 0.0556 - val_mse: 0.0066 - learning_rate: 0.0010
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1108 - mae: 0.0514 - mse: 0.0050 - val_loss: 0.1088 - val_mae: 0.0551 - val_mse: 0.0064 - learning_rate: 0.0010
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1058 - mae: 0.0496 - mse: 0.0045 - val_loss: 0.1127 - val_mae: 0.0926 - val_mse: 0.0149 - learning_rate: 0.0010
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1013 - mae: 0.0482 - mse: 0.0045 - val_loss: 0.1015 - val_mae: 0.0644 - val_mse: 0.0081 - learning_rate: 0.0010
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0964 - mae: 0.0468 - mse: 0.0041 - val_loss: 0.0946 - val_mae: 0.0510 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0919 - mae: 0.0432 - mse: 0.0039 - val_loss: 0.0904 - val_mae: 0.0546 - val_mse: 0.0056 - learning_rate: 0.0010
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0870 - mae: 0.0411 - mse: 0.0033 - val_loss: 0.0890 - val_mae: 0.0684 - val_mse: 0.0084 - learning_rate: 0.0010
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0829 - mae: 0.0421 - mse: 0.0033 - val_loss: 0.0824 - val_mae: 0.0572 - val_mse: 0.0059 - learning_rate: 0.0010
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0787 - mae: 0.0397 - mse: 0.0032 - val_loss: 0.0786 - val_mae: 0.0543 - val_mse: 0.0060 - learning_rate: 0.0010
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0753 - mae: 0.0427 - mse: 0.0037 - val_loss: 0.0742 - val_mae: 0.0520 - val_mse: 0.0054 - learning_rate: 0.0010
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0710 - mae: 0.0405 - mse: 0.0033 - val_loss: 0.0763 - val_mae: 0.0867 - val_mse: 0.0114 - learning_rate: 0.0010
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0667 - mae: 0.0368 - mse: 0.0027 - val_loss: 0.0728 - val_mae: 0.0878 - val_mse: 0.0115 - learning_rate: 0.0010
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0636 - mae: 0.0403 - mse: 0.0032 - val_loss: 0.0647 - val_mae: 0.0690 - val_mse: 0.0069 - learning_rate: 0.0010
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0599 - mae: 0.0388 - mse: 0.0030 - val_loss: 0.0581 - val_mae: 0.0406 - val_mse: 0.0037 - learning_rate: 0.0010
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0563 - mae: 0.0371 - mse: 0.0027 - val_loss: 0.0558 - val_mae: 0.0542 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0536 - mae: 0.0385 - mse: 0.0031 - val_loss: 0.0565 - val_mae: 0.0806 - val_mse: 0.0085 - learning_rate: 0.0010
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0498 - mae: 0.0362 - mse: 0.0025 - val_loss: 0.0506 - val_mae: 0.0604 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0474 - mae: 0.0389 - mse: 0.0030 - val_loss: 0.0509 - val_mae: 0.0737 - val_mse: 0.0086 - learning_rate: 0.0010
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0443 - mae: 0.0358 - mse: 0.0027 - val_loss: 0.0464 - val_mae: 0.0678 - val_mse: 0.0068 - learning_rate: 0.0010
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0419 - mae: 0.0378 - mse: 0.0029 - val_loss: 0.0417 - val_mae: 0.0461 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0401 - mae: 0.0417 - mse: 0.0035 - val_loss: 0.0400 - val_mae: 0.0544 - val_mse: 0.0050 - learning_rate: 0.0010
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0377 - mae: 0.0399 - mse: 0.0033 - val_loss: 0.0365 - val_mae: 0.0423 - val_mse: 0.0039 - learning_rate: 0.0010
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0347 - mae: 0.0358 - mse: 0.0026 - val_loss: 0.0417 - val_mae: 0.0940 - val_mse: 0.0113 - learning_rate: 0.0010
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0329 - mae: 0.0370 - mse: 0.0029 - val_loss: 0.0321 - val_mae: 0.0416 - val_mse: 0.0037 - learning_rate: 0.0010
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0309 - mae: 0.0369 - mse: 0.0029 - val_loss: 0.0310 - val_mae: 0.0518 - val_mse: 0.0044 - learning_rate: 0.0010
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0284 - mae: 0.0336 - mse: 0.0023 - val_loss: 0.0301 - val_mae: 0.0545 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0269 - mae: 0.0348 - mse: 0.0025 - val_loss: 0.0268 - val_mae: 0.0443 - val_mse: 0.0036 - learning_rate: 0.0010
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0260 - mae: 0.0378 - mse: 0.0030 - val_loss: 0.0265 - val_mae: 0.0540 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0240 - mae: 0.0346 - mse: 0.0025 - val_loss: 0.0261 - val_mae: 0.0576 - val_mse: 0.0057 - learning_rate: 0.0010
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0228 - mae: 0.0365 - mse: 0.0027 - val_loss: 0.0245 - val_mae: 0.0552 - val_mse: 0.0053 - learning_rate: 0.0010
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0218 - mae: 0.0370 - mse: 0.0028 - val_loss: 0.0228 - val_mae: 0.0480 - val_mse: 0.0048 - learning_rate: 0.0010
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0201 - mae: 0.0346 - mse: 0.0024 - val_loss: 0.0233 - val_mae: 0.0579 - val_mse: 0.0065 - learning_rate: 0.0010
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0195 - mae: 0.0375 - mse: 0.0028 - val_loss: 0.0283 - val_mae: 0.0978 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0178 - mae: 0.0341 - mse: 0.0023 - val_loss: 0.0296 - val_mae: 0.1088 - val_mse: 0.0148 - learning_rate: 0.0010
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0180 - mae: 0.0403 - mse: 0.0031 - val_loss: 0.0210 - val_mae: 0.0619 - val_mse: 0.0068 - learning_rate: 0.0010
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0168 - mae: 0.0374 - mse: 0.0028 - val_loss: 0.0764 - val_mae: 0.2408 - val_mse: 0.0632 - learning_rate: 0.0010
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0161 - mae: 0.0388 - mse: 0.0030 - val_loss: 0.0369 - val_mae: 0.1378 - val_mse: 0.0244 - learning_rate: 0.0010
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0152 - mae: 0.0382 - mse: 0.0029 - val_loss: 0.0152 - val_mae: 0.0446 - val_mse: 0.0034 - learning_rate: 0.0010
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0143 - mae: 0.0357 - mse: 0.0027 - val_loss: 0.0142 - val_mae: 0.0414 - val_mse: 0.0031 - learning_rate: 0.0010
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - mae: 0.0332 - mse: 0.0021 - val_loss: 0.0319 - val_mae: 0.1295 - val_mse: 0.0214 - learning_rate: 0.0010
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - mae: 0.0361 - mse: 0.0025 - val_loss: 0.0201 - val_mae: 0.0879 - val_mse: 0.0102 - learning_rate: 0.0010
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0123 - mae: 0.0367 - mse: 0.0027 - val_loss: 0.0245 - val_mae: 0.1095 - val_mse: 0.0154 - learning_rate: 0.0010
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0113 - mae: 0.0330 - mse: 0.0023 - val_loss: 0.0148 - val_mae: 0.0635 - val_mse: 0.0062 - learning_rate: 0.0010
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0115 - mae: 0.0377 - mse: 0.0029 - val_loss: 0.0136 - val_mae: 0.0531 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - mae: 0.0363 - mse: 0.0029 - val_loss: 0.0110 - val_mae: 0.0403 - val_mse: 0.0033 - learning_rate: 0.0010
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0104 - mae: 0.0368 - mse: 0.0028 - val_loss: 0.0202 - val_mae: 0.1014 - val_mse: 0.0129 - learning_rate: 0.0010
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0095 - mae: 0.0342 - mse: 0.0024 - val_loss: 0.0120 - val_mae: 0.0490 - val_mse: 0.0051 - learning_rate: 0.0010
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0105 - mae: 0.0404 - mse: 0.0033 - val_loss: 0.0356 - val_mae: 0.1494 - val_mse: 0.0285 - learning_rate: 0.0010
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0108 - mae: 0.0431 - mse: 0.0037 - val_loss: 0.0135 - val_mae: 0.0662 - val_mse: 0.0067 - learning_rate: 0.0010
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0096 - mae: 0.0384 - mse: 0.0029 - val_loss: 0.0448 - val_mae: 0.1834 - val_mse: 0.0386 - learning_rate: 0.0010
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0086 - mae: 0.0356 - mse: 0.0026 - val_loss: 0.0090 - val_mae: 0.0452 - val_mse: 0.0033 - learning_rate: 2.0000e-04
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0074 - mae: 0.0305 - mse: 0.0019 - val_loss: 0.0099 - val_mae: 0.0533 - val_mse: 0.0045 - learning_rate: 2.0000e-04
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0072 - mae: 0.0307 - mse: 0.0019 - val_loss: 0.0087 - val_mae: 0.0411 - val_mse: 0.0035 - learning_rate: 2.0000e-04
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0072 - mae: 0.0317 - mse: 0.0021 - val_loss: 0.0091 - val_mae: 0.0444 - val_mse: 0.0040 - learning_rate: 2.0000e-04
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0068 - mae: 0.0294 - mse: 0.0018 - val_loss: 0.0094 - val_mae: 0.0526 - val_mse: 0.0045 - learning_rate: 2.0000e-04
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0072 - mae: 0.0330 - mse: 0.0023 - val_loss: 0.0079 - val_mae: 0.0400 - val_mse: 0.0031 - learning_rate: 2.0000e-04
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - mae: 0.0305 - mse: 0.0018 - val_loss: 0.0088 - val_mae: 0.0475 - val_mse: 0.0041 - learning_rate: 2.0000e-04
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0067 - mae: 0.0322 - mse: 0.0020 - val_loss: 0.0107 - val_mae: 0.0680 - val_mse: 0.0061 - learning_rate: 2.0000e-04
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0064 - mae: 0.0298 - mse: 0.0018 - val_loss: 0.0077 - val_mae: 0.0382 - val_mse: 0.0031 - learning_rate: 2.0000e-04
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0065 - mae: 0.0320 - mse: 0.0020 - val_loss: 0.0082 - val_mae: 0.0460 - val_mse: 0.0038 - learning_rate: 2.0000e-04
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0060 - mae: 0.0275 - mse: 0.0015 - val_loss: 0.0117 - val_mae: 0.0746 - val_mse: 0.0074 - learning_rate: 2.0000e-04
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0065 - mae: 0.0321 - mse: 0.0021 - val_loss: 0.0076 - val_mae: 0.0407 - val_mse: 0.0033 - learning_rate: 2.0000e-04
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0064 - mae: 0.0305 - mse: 0.0020 - val_loss: 0.0072 - val_mae: 0.0422 - val_mse: 0.0029 - learning_rate: 2.0000e-04
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mae: 0.0287 - mse: 0.0016 - val_loss: 0.0242 - val_mae: 0.1304 - val_mse: 0.0200 - learning_rate: 2.0000e-04
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0063 - mae: 0.0314 - mse: 0.0021 - val_loss: 0.0064 - val_mae: 0.0340 - val_mse: 0.0023 - learning_rate: 2.0000e-04
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0061 - mae: 0.0309 - mse: 0.0020 - val_loss: 0.0090 - val_mae: 0.0613 - val_mse: 0.0050 - learning_rate: 2.0000e-04
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0056 - mae: 0.0281 - mse: 0.0016 - val_loss: 0.0202 - val_mae: 0.1186 - val_mse: 0.0163 - learning_rate: 2.0000e-04
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0304 - mse: 0.0018 - val_loss: 0.0095 - val_mae: 0.0640 - val_mse: 0.0056 - learning_rate: 2.0000e-04
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mae: 0.0295 - mse: 0.0017 - val_loss: 0.0074 - val_mae: 0.0420 - val_mse: 0.0036 - learning_rate: 2.0000e-04
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0054 - mae: 0.0286 - mse: 0.0016 - val_loss: 0.0058 - val_mae: 0.0326 - val_mse: 0.0021 - learning_rate: 2.0000e-04
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mae: 0.0308 - mse: 0.0018 - val_loss: 0.0070 - val_mae: 0.0459 - val_mse: 0.0033 - learning_rate: 2.0000e-04
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0055 - mae: 0.0302 - mse: 0.0018 - val_loss: 0.0069 - val_mae: 0.0438 - val_mse: 0.0032 - learning_rate: 2.0000e-04
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0053 - mae: 0.0286 - mse: 0.0017 - val_loss: 0.0060 - val_mae: 0.0373 - val_mse: 0.0025 - learning_rate: 2.0000e-04
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0053 - mae: 0.0296 - mse: 0.0018 - val_loss: 0.0083 - val_mae: 0.0601 - val_mse: 0.0048 - learning_rate: 2.0000e-04
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0052 - mae: 0.0285 - mse: 0.0017 - val_loss: 0.0072 - val_mae: 0.0518 - val_mse: 0.0038 - learning_rate: 2.0000e-04
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049 - mae: 0.0275 - mse: 0.0015 - val_loss: 0.0059 - val_mae: 0.0411 - val_mse: 0.0026 - learning_rate: 4.0000e-05
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0051 - mae: 0.0302 - mse: 0.0018 - val_loss: 0.0053 - val_mae: 0.0322 - val_mse: 0.0021 - learning_rate: 4.0000e-05
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0047 - mae: 0.0268 - mse: 0.0015 - val_loss: 0.0056 - val_mae: 0.0381 - val_mse: 0.0024 - learning_rate: 4.0000e-05

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

print("Training Loss:", history.history.get('loss', []))
print("Validation Loss:", history.history.get('val_loss', []))
# Out:
# Training Loss: [0.8906253576278687, 0.4448351562023163, 0.3603033423423767, 0.3130526542663574, 0.2706664204597473, 0.2487586885690689, 0.22813189029693604, 0.21325461566448212, 0.20183956623077393, 0.19279874861240387, 0.183571919798851, 0.17545564472675323, 0.1706186681985855, 0.16346311569213867, 0.1577262282371521, 0.15159237384796143, 0.1463390439748764, 0.14032238721847534, 0.13451899588108063, 0.12929944694042206, 0.12415623664855957, 0.11901168525218964, 0.11423508822917938, 0.10920760780572891, 0.10446426272392273, 0.09986481070518494, 0.0952134057879448, 0.09061145782470703, 0.08634763211011887, 0.08190193772315979, 0.07803123444318771, 0.07433199137449265, 0.07001616805791855, 0.06622058898210526, 0.06254942715167999, 0.05921504646539688, 0.055713143199682236, 0.05272427201271057, 0.049275606870651245, 0.046656057238578796, 0.043488699942827225, 0.04119192063808441, 0.039467282593250275, 0.036794696003198624, 0.034200288355350494, 0.03218626230955124, 0.030352089554071426, 0.028184372931718826, 0.026844447478652, 0.025550521910190582, 0.023837754502892494, 0.022692766040563583, 0.02122182585299015, 0.019985726103186607, 0.019044244661927223, 0.017596464604139328, 0.01748965121805668, 0.016565389931201935, 0.015715889632701874, 0.01496654748916626, 0.013962463475763798, 0.013136192224919796, 0.012811177410185337, 0.011911393143236637, 0.011192027479410172, 0.011053510941565037, 0.010570022277534008, 0.010236161760985851, 0.009458822198212147, 0.010269217193126678, 0.010061662644147873, 0.009141715243458748, 0.008222279138863087, 0.007469897158443928, 0.00713076489046216, 0.007092348765581846, 0.007017428986728191, 0.0069197784177958965, 0.006581597961485386, 0.006596096791327, 0.006403104867786169, 0.0065538836643099785, 0.006037885323166847, 0.006466091610491276, 0.0062520503997802734, 0.005987168755382299, 0.006038231775164604, 0.005941737908869982, 0.005684894509613514, 0.005844866391271353, 0.005582045763731003, 0.0054632495157420635, 0.00559399276971817, 0.005578517913818359, 0.005399918183684349, 0.005302599631249905, 0.00515224551782012, 0.0048289187252521515, 0.0049002645537257195, 0.004701198544353247]
# Validation Loss: [0.28136637806892395, 0.24529099464416504, 0.20652805268764496, 0.20120638608932495, 0.196414053440094, 0.19214993715286255, 0.18917322158813477, 0.1873270720243454, 0.1819499135017395, 0.1775754690170288, 0.17345525324344635, 0.1714300960302353, 0.16381697356700897, 0.16075995564460754, 0.15420961380004883, 0.15033134818077087, 0.14404340088367462, 0.13931135833263397, 0.13539156317710876, 0.1289367526769638, 0.12352840602397919, 0.12031174451112747, 0.11352350562810898, 0.10877270996570587, 0.11272145807743073, 0.10149875283241272, 0.09459839761257172, 0.09038205444812775, 0.0889568105340004, 0.08241182565689087, 0.0785980150103569, 0.07416019588708878, 0.0763271152973175, 0.072750024497509, 0.06468067318201065, 0.05806497111916542, 0.05582467094063759, 0.05650070309638977, 0.050588320940732956, 0.050888705998659134, 0.04638141766190529, 0.041704293340444565, 0.04003644734621048, 0.03653234988451004, 0.041734468191862106, 0.03212270885705948, 0.031021004542708397, 0.030082520097494125, 0.026831159368157387, 0.02650562860071659, 0.02607744187116623, 0.02446930482983589, 0.022803310304880142, 0.023286011070013046, 0.028317326679825783, 0.02959703467786312, 0.02098788507282734, 0.07642648369073868, 0.036911360919475555, 0.015170717611908913, 0.01416865736246109, 0.03185155242681503, 0.020050210878252983, 0.024485833942890167, 0.014816630631685257, 0.013569194823503494, 0.010979185812175274, 0.020191561430692673, 0.011953326873481274, 0.035571835935115814, 0.01347715500742197, 0.04481105878949165, 0.008961948566138744, 0.009864686988294125, 0.008715770207345486, 0.009075799956917763, 0.009400926530361176, 0.007943199016153812, 0.008754387497901917, 0.010670785792171955, 0.007658467162400484, 0.008222007192671299, 0.011714889667928219, 0.007621449418365955, 0.007188389543443918, 0.02421574667096138, 0.006373153068125248, 0.00900275819003582, 0.02023814246058464, 0.009542597457766533, 0.007449663709849119, 0.0058411965146660805, 0.006953226402401924, 0.006898284424096346, 0.006042586639523506, 0.00826197862625122, 0.00721445819362998, 0.005907475482672453, 0.005320024210959673, 0.005622118711471558]

# %%
# mse
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# mae
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0233 - mse: 0.0010
# [0.005320024210959673, 0.0020650539081543684, 0.03224531188607216]

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.795504
# R2 Score: 0.795504
# Max Error: 0.270440

# %%
# make predictions
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp


# # Get predictions from the model
# predicted = model.predict(test_X)

# # Reshape the actual test labels and predictions to ensure proper shape
# test_label = test_Y.reshape(-1,1)
# predicted = np.array(predicted[:,0]).reshape(-1,1)

# # Get the length of training data
# len_t = len(train_X)

# # Inverse transform the predictions and actual values
# # This loop is denormalizing/inverse scaling the predictions and actual values
# for j in range(len_t, len_t + len(test_X)):
#     temp = data.iloc[j,3]  # Getting the original scale factor
#     # Inverse transform actual values
#     test_label[j - len_t] = test_label[j - len_t] * temp + temp
#     # Inverse transform predictions
#     predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Create figure and axis with specified size
    plt.figure(figsize=(15, 7))
    
    # Plot actual prices
    plt.plot(test_label, label='Actual Price', color='green')
    
    # Plot predicted prices
    plt.plot(predicted, label='Predicted Price', color='red')
    
    # Customize the plot
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add margins for better visibility
    plt.margins(x=0.02)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Show plot
    plt.show()

def plot_predictions_with_dates(test_label, predicted, dates, title="Stock Price Prediction"):
    plt.figure(figsize=(15, 6))
    
    # Plot with dates
    plt.plot(dates, test_label, label='Actual Price', color='blue', linewidth=2)
    plt.plot(dates, predicted, label='Predicted Price', color='red', linestyle='--', linewidth=2)
    
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Format date axis
    plt.gcf().autofmt_xdate()  # Angle and align the tick labels
    
    plt.tight_layout()
    plt.show()

# %%
from scipy.signal import savgol_filter

def plot_predictions(test_label, predicted, title="Actual V Stock Price Prediction"):
    # Apply smoothing to both lines
    window_length = 5  # Must be odd; adjust this value to control smoothing amount
    polyorder = 1
    
    # Smooth both actual and predicted values
    test_label_smooth = savgol_filter(test_label.flatten(), window_length, polyorder)
    predicted_smooth = savgol_filter(predicted.flatten(), window_length, polyorder)
    
    plt.figure(figsize=(15, 6))
    
    # Plot smoothed lines
    plt.plot(test_label_smooth, label='Actual Price', color='red')
    plt.plot(predicted_smooth, label='Predicted Price', color='blue')
    
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_predictions(test_label, predicted, "Actual V Stock Price Prediction")

# %%
# Performance Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Calculate performance metrics
mse = mean_squared_error(test_label, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_label, predicted)
mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100

# Print performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Squared Error (MSE): 93.84722710926395
# Root Mean Squared Error (RMSE): 9.6874778507754
# Mean Absolute Error (MAE): 7.193122715958055
# Mean Absolute Percentage Error (MAPE): 3.48%

# %%
# Save the trained model
model.save('improved_model.h5')  # Saves the entire model (architecture, weights, and optimizer state)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
