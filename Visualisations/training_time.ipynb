# %% [markdown]
# # Training Time Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import seaborn as sns

# %%
# Average training times and RMSE values for each model
models = ['CNN-LSTM', 'CNN-LSTM Improved', 'GRU-LSTM', 'XGBoost-LSTM']
training_times = [49.1, 122.8, 30.13, 119.4]  # in seconds
rmse_values = [18.96, 9.71, 12.90, 24.49]

# bar chart 
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax = sns.barplot(y=models, x=training_times, palette="Spectral")

# Put values at the end of the bars
for i, v in enumerate(training_times):
    ax.text(v + 1, i, f"{v:.1f}s", va='center', fontweight='bold')

plt.xlim(0, max(training_times) * 1.1)

plt.xlabel('Training Time (seconds)')
plt.title('Model Training Time Comparison')
plt.tight_layout()
plt.savefig('training_time_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# Time vs Performance scatterplot
plt.figure(figsize=(10, 8))
sns.set_style("whitegrid")

# Diff colors for diff models 
colors = ['b', 'g', 'r', 'purple']
scatter = plt.scatter(training_times, rmse_values, s=100, 
                     alpha=0.7, color=colors)  

# Add model names
for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], rmse_values[i]), 
                 xytext=(0, 10), textcoords='offset points', 
                 ha='center', va='bottom')

plt.xlabel('Training Time (seconds)')
plt.ylabel('RMSE (lower is better)')
plt.title('Performance vs. Training Time Trade-off')
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig('performance_vs_time.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\timoz\AppData\Local\Temp\ipykernel_51048\975265571.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=models, x=training_times, palette="Spectral")

# %%
print(f"training_times length: {len(training_times)}")
print(f"rmse_values length: {len(rmse_values)}")
# Out:
# training_times length: 4
# rmse_values length: 5
