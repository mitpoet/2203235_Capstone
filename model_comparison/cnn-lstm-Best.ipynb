# %%
import numpy as np # linear algebra
import pandas as pd 
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('../model_comparison/meta.csv')
data.head()
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Reset index
data.reset_index(drop=True, inplace=True)

# Select numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Fill NaN values in numeric columns with the mean of those columns
data[numeric_data.columns] = data[numeric_data.columns].fillna(numeric_data.mean())

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Calculate moving average
ma_day = [5, 10, 20, 50]  # Common short-term and long-term windows
for ma in ma_day:
    column_name = f"MA for {ma} days"
    data[column_name] = data['Close'].rolling(window=ma).mean()

# Calculate Exponential moving average
for ma in ma_day:
    column_name = f"EMA for {ma} days"
    data[column_name] = data['Close'].ewm(span=ma, adjust=False).mean()

# Volatility (Standard Deviation): Capture price fluctuations:
# for ma in ma_day:
#     column_name = f"Volatility_{ma}d"
#     data[column_name] = data['Close'].rolling(window=ma).std()

# Calculate RSI
def compute_RSI(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data['RSI_14'] = compute_RSI(data)

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date    Open     High       Low     Close     Volume  \
# 0     2012-05-18   42.05   45.000   38.0000   38.2318  573576400
# 1     2012-05-21   36.53   36.660   33.0000   34.0300  168192700
# 2     2012-05-22   32.61   33.590   30.9400   31.0000  101786600
# 3     2012-05-23   31.37   32.500   31.3600   32.0000   73600000
# 4     2012-05-24   32.95   33.210   31.7700   33.0300   50237200
# ...          ...     ...      ...       ...       ...        ...
# 2668  2022-12-23  116.03  118.175  115.5350  118.0400   17796625
# 2669  2022-12-27  117.93  118.600  116.0501  116.8800   21392311
# 2670  2022-12-28  116.25  118.150  115.5100  115.6200   19612473
# 2671  2022-12-29  116.40  121.030  115.7700  120.2600   22366192
# 2672  2022-12-30  118.16  120.420  117.7400  120.3400   19583825
#
#       MA for 5 days  MA for 10 days  MA for 20 days  MA for 50 days  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4          33.65836             NaN             NaN             NaN
# ...             ...             ...             ...             ...
# 2668      117.29800         117.852         117.025        114.2838
# 2669      117.77800         118.069         117.430        114.0862
# 2670      117.48400         117.616         117.738        113.7178
# 2671      117.58400         117.483         117.846        113.4670
# 2672      118.22800         117.902         117.841        113.2092
#
#       EMA for 5 days  EMA for 10 days  EMA for 20 days  EMA for 50 days  \
# 0          38.231800        38.231800        38.231800        38.231800
# 1          36.831200        37.467836        37.831629        38.067024
# 2          34.887467        36.291866        37.180997        37.789885
# 3          33.924978        35.511527        36.687569        37.562831
# 4          33.626652        35.060340        36.339229        37.385073
# ...              ...              ...              ...              ...
# 2668      117.800705       117.531164       116.637103       119.704974
# 2669      117.493804       117.412770       116.660236       119.594191
# 2670      116.869202       117.086812       116.561166       119.438340
# 2671      117.999468       117.663755       116.913436       119.470562
# 2672      118.779646       118.150345       117.239776       119.504658
#
#          RSI_14      MACD
# 0           NaN  0.000000
# 1           NaN -0.335186
# 2           NaN -0.835686
# 3           NaN -1.138520
# 4           NaN -1.280644
# ...         ...       ...
# 2668  44.652862  0.867627
# 2669  54.070796  0.765449
# 2670  52.416357  0.576159
# 2671  56.451191  0.791432
# 2672  55.885472  0.957455
#
# [2673 rows x 16 columns]
#                   count          mean           std           min  \
# Open             2673.0  1.479633e+02  8.696828e+01  1.808000e+01
# High             2673.0  1.498468e+02  8.805465e+01  1.827000e+01
# Low              2673.0  1.460862e+02  8.591529e+01  1.755000e+01
# Close            2673.0  1.479917e+02  8.699929e+01  1.772900e+01
# Volume           2673.0  3.115405e+07  2.721709e+07  5.913066e+06
# MA for 5 days    2669.0  1.480981e+02  8.692966e+01  1.846140e+01
# MA for 10 days   2664.0  1.482359e+02  8.686269e+01  1.877955e+01
# MA for 20 days   2654.0  1.485193e+02  8.673551e+01  1.925918e+01
# MA for 50 days   2624.0  1.493997e+02  8.630554e+01  2.017572e+01
# EMA for 5 days   2673.0  1.479314e+02  8.694024e+01  1.846579e+01
# EMA for 10 days  2673.0  1.478571e+02  8.690014e+01  1.890858e+01
# EMA for 20 days  2673.0  1.477109e+02  8.681879e+01  1.968711e+01
# EMA for 50 days  2673.0  1.472468e+02  8.654123e+01  2.106646e+01
# RSI_14           2660.0  5.344210e+01  1.577691e+01  9.768073e+00
# MACD             2673.0  2.043057e-01  4.256432e+00 -2.904631e+01
#
#                           25%           50%           75%           max
# Open             7.780000e+01  1.422600e+02  1.913600e+02  3.816800e+02
# High             7.853000e+01  1.445600e+02  1.940300e+02  3.843300e+02
# Low              7.705000e+01  1.408700e+02  1.884700e+02  3.788100e+02
# Close            7.783000e+01  1.422800e+02  1.912900e+02  3.821800e+02
# Volume           1.618928e+07  2.313342e+07  3.599420e+07  5.735764e+08
# MA for 5 days    7.780600e+01  1.422620e+02  1.913780e+02  3.790300e+02
# MA for 10 days   7.777912e+01  1.418685e+02  1.917312e+02  3.786580e+02
# MA for 20 days   7.751544e+01  1.434165e+02  1.920813e+02  3.734220e+02
# MA for 50 days   7.745560e+01  1.471485e+02  1.906790e+02  3.637544e+02
# EMA for 5 days   7.757111e+01  1.420655e+02  1.913073e+02  3.782458e+02
# EMA for 10 days  7.745753e+01  1.418166e+02  1.908980e+02  3.763954e+02
# EMA for 20 days  7.711146e+01  1.424947e+02  1.903275e+02  3.728644e+02
# EMA for 50 days  7.669829e+01  1.454013e+02  1.891680e+02  3.629571e+02
# RSI_14           4.233863e+01  5.403817e+01  6.516629e+01  9.498106e+01
# MACD            -8.841952e-01  6.689780e-01  2.167294e+00  1.363001e+01

# %%
data.dropna(inplace=True)
data.head(500)
# Out:
#            Date    Open   High     Low  Close     Volume  MA for 5 days  \
# 49   2012-07-30  23.995  24.04  23.030  23.15   29285900       26.29800
# 50   2012-07-31  23.370  23.37  21.610  21.71   56179400       24.95000
# 51   2012-08-01  21.500  21.58  20.840  20.88   44604400       23.25800
# 52   2012-08-02  20.770  20.84  19.820  20.04   56374500       21.89700
# 53   2012-08-03  20.360  22.16  19.900  21.09   80647000       21.37400
# ..          ...     ...    ...     ...    ...        ...            ...
# 544  2014-07-21  68.810  69.96  68.500  69.40   49431600       67.81096
# 545  2014-07-22  69.760  69.77  68.610  69.27   40301800       68.23196
# 546  2014-07-23  69.740  71.33  69.610  71.29   77435900       68.95796
# 547  2014-07-24  75.960  76.74  74.510  74.98  124006900       70.67198
# 548  2014-07-25  74.990  75.67  74.662  75.19   45823100       72.02600
#
#      MA for 10 days  MA for 20 days  MA for 50 days  EMA for 5 days  \
# 49         27.52000       29.237800       29.838636       25.546291
# 50         26.88200       28.784750       29.508200       24.267527
# 51         26.05900       28.268750       29.245200       23.138351
# 52         25.16300       27.697250       29.026000       22.105568
# 53         24.39600       27.165250       28.807800       21.767045
# ..              ...             ...             ...             ...
# 544        66.58973       66.626865       64.001716       68.007206
# 545        67.24073       66.821865       64.242316       68.428138
# 546        67.87273       67.100365       64.471516       69.382092
# 547        68.88348       67.477365       64.774516       71.248061
# 548        69.76848       67.880365       65.093716       72.562041
#
#      EMA for 10 days  EMA for 20 days  EMA for 50 days     RSI_14      MACD
# 49         27.046144        28.449746        30.538853  15.733114 -1.525536
# 50         26.075936        27.807865        30.192623  14.602446 -1.869091
# 51         25.131220        27.148068        29.827422  13.890909 -2.183168
# 52         24.205544        26.471110        29.443602  13.172414 -2.471369
# 53         23.639081        25.958623        29.116010  22.638623 -2.585243
# ..               ...              ...              ...        ...       ...
# 544        67.283914        66.478537        64.769416  56.251778  1.037495
# 545        67.645020        66.744391        64.945909  53.726471  1.134074
# 546        68.307744        67.177306        65.194697  64.538726  1.357958
# 547        69.520881        67.920420        65.578435  71.536342  1.812249
# 548        70.551630        68.612761        65.955359  75.534944  2.164275
#
# [500 rows x 16 columns]

# %%
# updated Code

feature_columns = [
    'Close',          # Most important feature (direct price information)
    'Low',            # Important price-related feature
    'High',           # Important price-related feature
    'Open',           # Important price-related feature
    'EMA for 5 days', # Short-term trend indicator
    'MA for 5 days',  # Short-term trend indicator
    'RSI_14'          # Momentum indicator
]

from sklearn.model_selection import train_test_split
import numpy as np

X = []
Y = []
window_size = 15

# Iterating through the dataset to create inputs and targets
for i in range(1, len(df) - window_size - 1, 1):
    first_close = df.iloc[i, df.columns.get_loc('Close')]  # Normalize using "Close" price
    temp = []
    temp2 = []
    
    for j in range(window_size):
        # Normalize each feature in the feature_columns list
        normalized_features = []
        for feature in feature_columns:
            if feature == 'Close':
                # Normalize "Close" relative to the first_close
                normalized_value = (df.iloc[i + j, df.columns.get_loc(feature)] - first_close) / first_close
            else:
                # For other features, normalize them directly (or use their raw values if normalization isn't required)
                normalized_value = df.iloc[i + j, df.columns.get_loc(feature)]
            normalized_features.append(normalized_value)
        
        # Append the normalized features for this time step
        temp.append(normalized_features)
    
    # Calculate the target (normalized change in "Close" price)
    target = (df.iloc[i + window_size, df.columns.get_loc('Close')] - first_close) / first_close
    temp2.append(target)
    
    # Append the input and target to X and Y
    X.append(np.array(temp))  # Each sample has shape (window_size, len(feature_columns))
    Y.append(np.array(temp2).reshape(1, 1))

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# Converting lists to numpy arrays
train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

# Verify the shape of train_X
print("Shape of train_X before reshaping:", train_X.shape)

# Reshaping the data for CNN models
# Assuming train_X has shape (num_samples, window_size, num_features)
train_X = train_X.reshape(train_X.shape[0], 1, train_X.shape[1], train_X.shape[2])  
test_X = test_X.reshape(test_X.shape[0], 1, test_X.shape[1], test_X.shape[2])

# Printing the number of training and testing samples
print("Shape of train_X after reshaping:", train_X.shape)
print("Shape of test_X after reshaping:", test_X.shape)
print("Number of training samples:", len(train_X))
print("Number of testing samples:", len(test_X))
# Out:
# Shape of train_X before reshaping: (2085, 15, 7)
# Shape of train_X after reshaping: (2085, 1, 15, 7)
# Shape of test_X after reshaping: (522, 1, 15, 7)
# Number of training samples: 2085
# Number of testing samples: 522

# %%
# Check if there are any NaN values

print(np.isnan(train_X).any(), np.isnan(train_Y).any())
print(np.isinf(train_X).any(), np.isinf(train_Y).any())
# Out:
# False False
# False False

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam


from tensorflow.keras.layers import Layer
from tensorflow.keras.saving import register_keras_serializable

@register_keras_serializable(package='CustomLayers', name='AttentionLayer')
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.nn.tanh(tf.matmul(x, self.W) + self.b)
        at = tf.nn.softmax(et, axis=1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

    def get_config(self):
        config = super(AttentionLayer, self).get_config()
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)


# Create the model
model = tf.keras.Sequential()

# Enhanced CNN layers with BatchNormalization and LeakyReLU
model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                               input_shape=(None, 100, 1))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Flatten()))

# Enhanced LSTM layers (removed clip_norm parameter)
model.add(Bidirectional(LSTM(128, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(64, return_sequences=True,  # Set return_sequences=True for Attention
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Add Attention Layer here
model.add(AttentionLayer())

# Dense layers with regularization
model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# Optimizer with gradient clipping (clipnorm moved here)
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

model.compile(optimizer=optimizer,
             loss='mse',
             metrics=['mse', 'mae'])

# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )
]

# Train the model
history = model.fit(
    train_X, 
    train_Y,
    validation_data=(test_X, test_Y),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/100
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.0921 - mae: 0.6967 - mse: 0.8022 - val_loss: 0.2182 - val_mae: 0.0826 - val_mse: 0.0113 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4906 - mae: 0.4246 - mse: 0.2911 - val_loss: 0.2003 - val_mae: 0.0750 - val_mse: 0.0104 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3300 - mae: 0.2926 - mse: 0.1410 - val_loss: 0.1981 - val_mae: 0.0808 - val_mse: 0.0114 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2861 - mae: 0.2471 - mse: 0.1000 - val_loss: 0.1945 - val_mae: 0.0741 - val_mse: 0.0105 - learning_rate: 0.0010
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2529 - mae: 0.2076 - mse: 0.0697 - val_loss: 0.1902 - val_mae: 0.0733 - val_mse: 0.0093 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2310 - mae: 0.1753 - mse: 0.0510 - val_loss: 0.1875 - val_mae: 0.0719 - val_mse: 0.0100 - learning_rate: 0.0010
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2151 - mae: 0.1519 - mse: 0.0385 - val_loss: 0.1845 - val_mae: 0.0763 - val_mse: 0.0107 - learning_rate: 0.0010
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2085 - mae: 0.1470 - mse: 0.0356 - val_loss: 0.1810 - val_mae: 0.0759 - val_mse: 0.0112 - learning_rate: 0.0010
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1926 - mae: 0.1184 - mse: 0.0237 - val_loss: 0.1760 - val_mae: 0.0735 - val_mse: 0.0103 - learning_rate: 0.0010
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1865 - mae: 0.1166 - mse: 0.0219 - val_loss: 0.1711 - val_mae: 0.0762 - val_mse: 0.0097 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1783 - mae: 0.1048 - mse: 0.0180 - val_loss: 0.1674 - val_mae: 0.0818 - val_mse: 0.0104 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1711 - mae: 0.0953 - mse: 0.0153 - val_loss: 0.1612 - val_mae: 0.0722 - val_mse: 0.0088 - learning_rate: 0.0010
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1632 - mae: 0.0854 - mse: 0.0121 - val_loss: 0.1563 - val_mae: 0.0717 - val_mse: 0.0087 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1585 - mae: 0.0859 - mse: 0.0121 - val_loss: 0.1515 - val_mae: 0.0711 - val_mse: 0.0086 - learning_rate: 0.0010
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1525 - mae: 0.0791 - mse: 0.0108 - val_loss: 0.1463 - val_mae: 0.0676 - val_mse: 0.0083 - learning_rate: 0.0010
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1465 - mae: 0.0750 - mse: 0.0097 - val_loss: 0.1411 - val_mae: 0.0684 - val_mse: 0.0079 - learning_rate: 0.0010
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1398 - mae: 0.0686 - mse: 0.0080 - val_loss: 0.1356 - val_mae: 0.0614 - val_mse: 0.0074 - learning_rate: 0.0010
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1362 - mae: 0.0725 - mse: 0.0090 - val_loss: 0.1311 - val_mae: 0.0622 - val_mse: 0.0075 - learning_rate: 0.0010
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1308 - mae: 0.0701 - mse: 0.0084 - val_loss: 0.1256 - val_mae: 0.0627 - val_mse: 0.0069 - learning_rate: 0.0010
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1237 - mae: 0.0601 - mse: 0.0063 - val_loss: 0.1209 - val_mae: 0.0596 - val_mse: 0.0071 - learning_rate: 0.0010
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1184 - mae: 0.0578 - mse: 0.0059 - val_loss: 0.1151 - val_mae: 0.0623 - val_mse: 0.0063 - learning_rate: 0.0010
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1131 - mae: 0.0555 - mse: 0.0055 - val_loss: 0.1095 - val_mae: 0.0517 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1085 - mae: 0.0559 - mse: 0.0057 - val_loss: 0.1048 - val_mae: 0.0524 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1031 - mae: 0.0510 - mse: 0.0049 - val_loss: 0.0995 - val_mae: 0.0511 - val_mse: 0.0050 - learning_rate: 0.0010
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0987 - mae: 0.0533 - mse: 0.0052 - val_loss: 0.0955 - val_mae: 0.0523 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0933 - mae: 0.0480 - mse: 0.0044 - val_loss: 0.0921 - val_mae: 0.0667 - val_mse: 0.0066 - learning_rate: 0.0010
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0886 - mae: 0.0475 - mse: 0.0042 - val_loss: 0.0865 - val_mae: 0.0537 - val_mse: 0.0054 - learning_rate: 0.0010
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0840 - mae: 0.0458 - mse: 0.0040 - val_loss: 0.0832 - val_mae: 0.0604 - val_mse: 0.0063 - learning_rate: 0.0010
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0798 - mae: 0.0460 - mse: 0.0041 - val_loss: 0.0810 - val_mae: 0.0771 - val_mse: 0.0084 - learning_rate: 0.0010
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0752 - mae: 0.0434 - mse: 0.0035 - val_loss: 0.0733 - val_mae: 0.0485 - val_mse: 0.0047 - learning_rate: 0.0010
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0707 - mae: 0.0408 - mse: 0.0030 - val_loss: 0.0693 - val_mae: 0.0478 - val_mse: 0.0046 - learning_rate: 0.0010
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0675 - mae: 0.0435 - mse: 0.0037 - val_loss: 0.0663 - val_mae: 0.0525 - val_mse: 0.0053 - learning_rate: 0.0010
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0632 - mae: 0.0406 - mse: 0.0032 - val_loss: 0.0618 - val_mae: 0.0512 - val_mse: 0.0045 - learning_rate: 0.0010
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0598 - mae: 0.0403 - mse: 0.0033 - val_loss: 0.0595 - val_mae: 0.0604 - val_mse: 0.0057 - learning_rate: 0.0010
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0564 - mae: 0.0409 - mse: 0.0033 - val_loss: 0.0615 - val_mae: 0.0930 - val_mse: 0.0109 - learning_rate: 0.0010
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0525 - mae: 0.0380 - mse: 0.0028 - val_loss: 0.0615 - val_mae: 0.1043 - val_mse: 0.0141 - learning_rate: 0.0010
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0502 - mae: 0.0418 - mse: 0.0035 - val_loss: 0.0515 - val_mae: 0.0721 - val_mse: 0.0072 - learning_rate: 0.0010
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0464 - mae: 0.0382 - mse: 0.0028 - val_loss: 0.0557 - val_mae: 0.1054 - val_mse: 0.0142 - learning_rate: 0.0010
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0434 - mae: 0.0370 - mse: 0.0026 - val_loss: 0.0460 - val_mae: 0.0700 - val_mse: 0.0072 - learning_rate: 0.0010
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0413 - mae: 0.0402 - mse: 0.0030 - val_loss: 0.0415 - val_mae: 0.0554 - val_mse: 0.0052 - learning_rate: 0.0010
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0384 - mae: 0.0376 - mse: 0.0028 - val_loss: 0.0401 - val_mae: 0.0645 - val_mse: 0.0063 - learning_rate: 0.0010
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0362 - mae: 0.0388 - mse: 0.0029 - val_loss: 0.0379 - val_mae: 0.0672 - val_mse: 0.0063 - learning_rate: 0.0010
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0339 - mae: 0.0376 - mse: 0.0029 - val_loss: 0.0354 - val_mae: 0.0649 - val_mse: 0.0060 - learning_rate: 0.0010
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0319 - mae: 0.0384 - mse: 0.0030 - val_loss: 0.0318 - val_mae: 0.0448 - val_mse: 0.0043 - learning_rate: 0.0010
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0299 - mae: 0.0364 - mse: 0.0029 - val_loss: 0.0317 - val_mae: 0.0614 - val_mse: 0.0060 - learning_rate: 0.0010
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0277 - mae: 0.0343 - mse: 0.0024 - val_loss: 0.0295 - val_mae: 0.0598 - val_mse: 0.0055 - learning_rate: 0.0010
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0260 - mae: 0.0341 - mse: 0.0024 - val_loss: 0.0258 - val_mae: 0.0392 - val_mse: 0.0034 - learning_rate: 0.0010
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0243 - mae: 0.0347 - mse: 0.0024 - val_loss: 0.0259 - val_mae: 0.0543 - val_mse: 0.0050 - learning_rate: 0.0010
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0230 - mae: 0.0353 - mse: 0.0024 - val_loss: 0.0250 - val_mae: 0.0629 - val_mse: 0.0054 - learning_rate: 0.0010
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0224 - mae: 0.0394 - mse: 0.0031 - val_loss: 0.0536 - val_mae: 0.1764 - val_mse: 0.0352 - learning_rate: 0.0010
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0217 - mae: 0.0419 - mse: 0.0035 - val_loss: 0.0224 - val_mae: 0.0581 - val_mse: 0.0051 - learning_rate: 0.0010
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0197 - mae: 0.0363 - mse: 0.0026 - val_loss: 0.0227 - val_mae: 0.0704 - val_mse: 0.0065 - learning_rate: 0.0010
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0181 - mae: 0.0344 - mse: 0.0023 - val_loss: 0.0193 - val_mae: 0.0443 - val_mse: 0.0042 - learning_rate: 0.0010
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0176 - mae: 0.0365 - mse: 0.0027 - val_loss: 0.0170 - val_mae: 0.0398 - val_mse: 0.0028 - learning_rate: 0.0010
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0172 - mae: 0.0385 - mse: 0.0031 - val_loss: 0.0434 - val_mae: 0.1611 - val_mse: 0.0301 - learning_rate: 0.0010
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0158 - mae: 0.0368 - mse: 0.0027 - val_loss: 0.0200 - val_mae: 0.0725 - val_mse: 0.0076 - learning_rate: 0.0010
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0150 - mae: 0.0372 - mse: 0.0027 - val_loss: 0.0237 - val_mae: 0.0963 - val_mse: 0.0120 - learning_rate: 0.0010
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0140 - mae: 0.0351 - mse: 0.0024 - val_loss: 0.0197 - val_mae: 0.0808 - val_mse: 0.0087 - learning_rate: 0.0010
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0135 - mae: 0.0366 - mse: 0.0027 - val_loss: 0.0224 - val_mae: 0.0978 - val_mse: 0.0120 - learning_rate: 0.0010
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0130 - mae: 0.0371 - mse: 0.0028 - val_loss: 0.0130 - val_mae: 0.0415 - val_mse: 0.0033 - learning_rate: 2.0000e-04
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0118 - mae: 0.0318 - mse: 0.0021 - val_loss: 0.0140 - val_mae: 0.0485 - val_mse: 0.0045 - learning_rate: 2.0000e-04
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0114 - mae: 0.0312 - mse: 0.0020 - val_loss: 0.0130 - val_mae: 0.0460 - val_mse: 0.0037 - learning_rate: 2.0000e-04
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0113 - mae: 0.0316 - mse: 0.0022 - val_loss: 0.0160 - val_mae: 0.0721 - val_mse: 0.0070 - learning_rate: 2.0000e-04
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0109 - mae: 0.0312 - mse: 0.0020 - val_loss: 0.0118 - val_mae: 0.0379 - val_mse: 0.0030 - learning_rate: 2.0000e-04
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0109 - mae: 0.0317 - mse: 0.0022 - val_loss: 0.0140 - val_mae: 0.0554 - val_mse: 0.0053 - learning_rate: 2.0000e-04
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0105 - mae: 0.0298 - mse: 0.0019 - val_loss: 0.0161 - val_mae: 0.0768 - val_mse: 0.0077 - learning_rate: 2.0000e-04
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0104 - mae: 0.0312 - mse: 0.0020 - val_loss: 0.0134 - val_mae: 0.0620 - val_mse: 0.0051 - learning_rate: 2.0000e-04
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0101 - mae: 0.0292 - mse: 0.0018 - val_loss: 0.0129 - val_mae: 0.0582 - val_mse: 0.0046 - learning_rate: 2.0000e-04
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0101 - mae: 0.0306 - mse: 0.0019 - val_loss: 0.0110 - val_mae: 0.0393 - val_mse: 0.0030 - learning_rate: 2.0000e-04
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0101 - mae: 0.0323 - mse: 0.0021 - val_loss: 0.0117 - val_mae: 0.0453 - val_mse: 0.0038 - learning_rate: 2.0000e-04
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0099 - mae: 0.0307 - mse: 0.0020 - val_loss: 0.0103 - val_mae: 0.0369 - val_mse: 0.0025 - learning_rate: 2.0000e-04
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0097 - mae: 0.0311 - mse: 0.0019 - val_loss: 0.0100 - val_mae: 0.0344 - val_mse: 0.0024 - learning_rate: 2.0000e-04
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0094 - mae: 0.0301 - mse: 0.0018 - val_loss: 0.0097 - val_mae: 0.0356 - val_mse: 0.0023 - learning_rate: 2.0000e-04
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0093 - mae: 0.0305 - mse: 0.0019 - val_loss: 0.0110 - val_mae: 0.0490 - val_mse: 0.0037 - learning_rate: 2.0000e-04
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0094 - mae: 0.0312 - mse: 0.0021 - val_loss: 0.0135 - val_mae: 0.0694 - val_mse: 0.0063 - learning_rate: 2.0000e-04
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0088 - mae: 0.0288 - mse: 0.0017 - val_loss: 0.0160 - val_mae: 0.0854 - val_mse: 0.0090 - learning_rate: 2.0000e-04
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0090 - mae: 0.0320 - mse: 0.0020 - val_loss: 0.0131 - val_mae: 0.0689 - val_mse: 0.0062 - learning_rate: 2.0000e-04
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0086 - mae: 0.0295 - mse: 0.0018 - val_loss: 0.0123 - val_mae: 0.0650 - val_mse: 0.0055 - learning_rate: 2.0000e-04
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0083 - mae: 0.0288 - mse: 0.0016 - val_loss: 0.0087 - val_mae: 0.0326 - val_mse: 0.0021 - learning_rate: 4.0000e-05
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0082 - mae: 0.0279 - mse: 0.0016 - val_loss: 0.0088 - val_mae: 0.0334 - val_mse: 0.0022 - learning_rate: 4.0000e-05
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0081 - mae: 0.0279 - mse: 0.0016 - val_loss: 0.0085 - val_mae: 0.0321 - val_mse: 0.0021 - learning_rate: 4.0000e-05
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0081 - mae: 0.0287 - mse: 0.0016 - val_loss: 0.0085 - val_mae: 0.0323 - val_mse: 0.0020 - learning_rate: 4.0000e-05
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0078 - mae: 0.0268 - mse: 0.0014 - val_loss: 0.0096 - val_mae: 0.0474 - val_mse: 0.0033 - learning_rate: 4.0000e-05
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0078 - mae: 0.0274 - mse: 0.0015 - val_loss: 0.0083 - val_mae: 0.0318 - val_mse: 0.0019 - learning_rate: 4.0000e-05
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0082 - mae: 0.0300 - mse: 0.0019 - val_loss: 0.0085 - val_mae: 0.0341 - val_mse: 0.0022 - learning_rate: 4.0000e-05
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0078 - mae: 0.0270 - mse: 0.0015 - val_loss: 0.0100 - val_mae: 0.0516 - val_mse: 0.0038 - learning_rate: 4.0000e-05
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0082 - mae: 0.0302 - mse: 0.0020 - val_loss: 0.0081 - val_mae: 0.0325 - val_mse: 0.0019 - learning_rate: 4.0000e-05
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0078 - mae: 0.0274 - mse: 0.0016 - val_loss: 0.0089 - val_mae: 0.0429 - val_mse: 0.0028 - learning_rate: 4.0000e-05
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0077 - mae: 0.0279 - mse: 0.0015 - val_loss: 0.0090 - val_mae: 0.0418 - val_mse: 0.0029 - learning_rate: 4.0000e-05
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0077 - mae: 0.0267 - mse: 0.0015 - val_loss: 0.0099 - val_mae: 0.0524 - val_mse: 0.0038 - learning_rate: 4.0000e-05
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0076 - mae: 0.0273 - mse: 0.0015 - val_loss: 0.0083 - val_mae: 0.0366 - val_mse: 0.0022 - learning_rate: 4.0000e-05
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0078 - mae: 0.0282 - mse: 0.0017 - val_loss: 0.0083 - val_mae: 0.0380 - val_mse: 0.0023 - learning_rate: 4.0000e-05
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0076 - mae: 0.0282 - mse: 0.0016 - val_loss: 0.0079 - val_mae: 0.0316 - val_mse: 0.0019 - learning_rate: 8.0000e-06
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - mae: 0.0264 - mse: 0.0014 - val_loss: 0.0079 - val_mae: 0.0325 - val_mse: 0.0019 - learning_rate: 8.0000e-06
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - mae: 0.0261 - mse: 0.0014 - val_loss: 0.0078 - val_mae: 0.0314 - val_mse: 0.0019 - learning_rate: 8.0000e-06
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0075 - mae: 0.0275 - mse: 0.0016 - val_loss: 0.0078 - val_mae: 0.0312 - val_mse: 0.0018 - learning_rate: 8.0000e-06
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - mae: 0.0264 - mse: 0.0014 - val_loss: 0.0081 - val_mae: 0.0358 - val_mse: 0.0021 - learning_rate: 8.0000e-06
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0076 - mae: 0.0285 - mse: 0.0017 - val_loss: 0.0077 - val_mae: 0.0309 - val_mse: 0.0018 - learning_rate: 8.0000e-06
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0075 - mae: 0.0279 - mse: 0.0016 - val_loss: 0.0079 - val_mae: 0.0335 - val_mse: 0.0019 - learning_rate: 8.0000e-06
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0073 - mae: 0.0266 - mse: 0.0014 - val_loss: 0.0077 - val_mae: 0.0319 - val_mse: 0.0018 - learning_rate: 8.0000e-06

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

print("Training Loss:", history.history.get('loss', []))
print("Validation Loss:", history.history.get('val_loss', []))
# Out:
# Training Loss: [0.8389244079589844, 0.43786847591400146, 0.3275325894355774, 0.2790830433368683, 0.24996569752693176, 0.22735269367694855, 0.21358157694339752, 0.20392246544361115, 0.19109074771404266, 0.1836654245853424, 0.17722533643245697, 0.16932269930839539, 0.16209374368190765, 0.1574820727109909, 0.15175026655197144, 0.14500726759433746, 0.13872642815113068, 0.13497813045978546, 0.12885934114456177, 0.12272664159536362, 0.11710618436336517, 0.11176876723766327, 0.10702329128980637, 0.1019773781299591, 0.09710108488798141, 0.09196271747350693, 0.08746830374002457, 0.0828770250082016, 0.07860147207975388, 0.07425806671380997, 0.06993187218904495, 0.06648419052362442, 0.06226714327931404, 0.05855164676904678, 0.05544726923108101, 0.05216945335268974, 0.04912043362855911, 0.045940447598695755, 0.042899083346128464, 0.04056737571954727, 0.037927597761154175, 0.03552522137761116, 0.03334665670990944, 0.031433019787073135, 0.029154444113373756, 0.027612736448645592, 0.025730129331350327, 0.024186382070183754, 0.022976407781243324, 0.02203856036067009, 0.02112668938934803, 0.019443975761532784, 0.018083618953824043, 0.017333999276161194, 0.01688818633556366, 0.015369720757007599, 0.014762446284294128, 0.01397302933037281, 0.013263666070997715, 0.01238292083144188, 0.011744620278477669, 0.011277821846306324, 0.011134610511362553, 0.010744820348918438, 0.01070069707930088, 0.010447866283357143, 0.01029323972761631, 0.010257435962557793, 0.01018989272415638, 0.010029565542936325, 0.009802408516407013, 0.009641207754611969, 0.00939166359603405, 0.009345641359686852, 0.009184116497635841, 0.008896555751562119, 0.008813894353806973, 0.00868368148803711, 0.008317778818309307, 0.008094961754977703, 0.008026654832065105, 0.008070914074778557, 0.007866833359003067, 0.007973424158990383, 0.007924018427729607, 0.007802375126630068, 0.007813522592186928, 0.007705822121351957, 0.007731717079877853, 0.007581294979900122, 0.007568735163658857, 0.007611462846398354, 0.007423819042742252, 0.0073601421900093555, 0.0073686931282281876, 0.007490326184779406, 0.007330288644880056, 0.007387763820588589, 0.007311745081096888, 0.007272602524608374]
# Validation Loss: [0.21815225481987, 0.2003180980682373, 0.19813786447048187, 0.19445063173770905, 0.19015787541866302, 0.18749041855335236, 0.18451371788978577, 0.1810392439365387, 0.1759996861219406, 0.17107219994068146, 0.16737274825572968, 0.16115672886371613, 0.15633107721805573, 0.15146571397781372, 0.14632926881313324, 0.14106032252311707, 0.13559870421886444, 0.13112755119800568, 0.12557561695575714, 0.1208721324801445, 0.11512980610132217, 0.1094985231757164, 0.10479079931974411, 0.09952642768621445, 0.09549984335899353, 0.09213197231292725, 0.0864643082022667, 0.08315832912921906, 0.08101288229227066, 0.0732981339097023, 0.06928297877311707, 0.06627065688371658, 0.061776209622621536, 0.05951732024550438, 0.061500899493694305, 0.06148933991789818, 0.051542676985263824, 0.055741168558597565, 0.04604741185903549, 0.041512053459882736, 0.0401262566447258, 0.0379122793674469, 0.035402052104473114, 0.03175627812743187, 0.031657617539167404, 0.029524045065045357, 0.02575736492872238, 0.02588936872780323, 0.025007648393511772, 0.05357100069522858, 0.02243475429713726, 0.022666191682219505, 0.019278787076473236, 0.016997607424855232, 0.04343857616186142, 0.01998193748295307, 0.02374192513525486, 0.01970352791249752, 0.02237975411117077, 0.012988440692424774, 0.014012271538376808, 0.01296346914023161, 0.015974055975675583, 0.01179756224155426, 0.013967500068247318, 0.016122257336974144, 0.013437689282000065, 0.012854369357228279, 0.011008908040821552, 0.011748787946999073, 0.010266055352985859, 0.010017587803304195, 0.009731005877256393, 0.011029076762497425, 0.013472093269228935, 0.01595292054116726, 0.01312295813113451, 0.012271083891391754, 0.008713383227586746, 0.00876372866332531, 0.008517461828887463, 0.008462991565465927, 0.0096331387758255, 0.00826308038085699, 0.008541007526218891, 0.010035404935479164, 0.008129151538014412, 0.008927363902330399, 0.009026794694364071, 0.009890454821288586, 0.008283748291432858, 0.008342621847987175, 0.007862541824579239, 0.007853946648538113, 0.00783296674489975, 0.0077501083724200726, 0.008076750673353672, 0.007714462466537952, 0.007862227037549019, 0.007722913287580013]

# %%
# mse
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# mae
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0234 - mse: 9.9124e-04
# [0.007714462466537952, 0.001789524802006781, 0.030918166041374207]

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.821819
# R2 Score: 0.821819
# Max Error: 0.253919

# %%
# make predictions
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Create figure and axis with specified size
    plt.figure(figsize=(15, 7))
    
    # Plot actual prices
    plt.plot(test_label, label='Actual Price', color='green')
    
    # Plot predicted prices
    plt.plot(predicted, label='Predicted Price', color='red')
    
    # Customize the plot
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add margins for better visibility
    plt.margins(x=0.02)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Show plot
    plt.show()

def plot_predictions_with_dates(test_label, predicted, dates, title="Stock Price Prediction"):
    plt.figure(figsize=(15, 6))
    
    # Plot with dates
    plt.plot(dates, test_label, label='Actual Price', color='blue', linewidth=2)
    plt.plot(dates, predicted, label='Predicted Price', color='red', linestyle='--', linewidth=2)
    
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Format date axis
    plt.gcf().autofmt_xdate()  # Angle and align the tick labels
    
    plt.tight_layout()
    plt.show()

# %%
from scipy.signal import savgol_filter

def plot_predictions(test_label, predicted, title="Actual V Stock Price Prediction"):
    # Apply smoothing to both lines
    window_length = 5  # Must be odd; adjust this value to control smoothing amount
    polyorder = 1
    
    # Smooth both actual and predicted values
    test_label_smooth = savgol_filter(test_label.flatten(), window_length, polyorder)
    predicted_smooth = savgol_filter(predicted.flatten(), window_length, polyorder)
    
    plt.figure(figsize=(15, 6))
    
    # Plot smoothed lines
    plt.plot(test_label_smooth, label='Actual Price', color='red')
    plt.plot(predicted_smooth, label='Predicted Price', color='blue')
    
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_predictions(test_label, predicted, "Actual V Stock Price Prediction")

# %%
# Performance Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Calculate performance metrics
mse = mean_squared_error(test_label, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_label, predicted)
mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100

# Print performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Squared Error (MSE): 91.16093897021538
# Root Mean Squared Error (RMSE): 9.547823781900009
# Mean Absolute Error (MAE): 7.148586741841753
# Mean Absolute Percentage Error (MAPE): 3.31%

# %%
# Save the trained model
model.save('../model_comparison/improved_model.keras')  # Saves the entire model (architecture, weights, and optimizer state)
