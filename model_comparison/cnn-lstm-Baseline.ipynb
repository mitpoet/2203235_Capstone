# %%
import numpy as np # linear algebra
import pandas as pd 
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv('./meta.csv')
data.head()
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Reset index
data.reset_index(drop=True, inplace=True)

# Select numeric columns
numeric_data = data.select_dtypes(include=[np.number])

# Fill NaN values in numeric columns with the mean of those columns
data[numeric_data.columns] = data[numeric_data.columns].fillna(numeric_data.mean())

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#          Date   Open   High    Low    Close     Volume
# 0  2012-05-18  42.05  45.00  38.00  38.2318  573576400
# 1  2012-05-21  36.53  36.66  33.00  34.0300  168192700
# 2  2012-05-22  32.61  33.59  30.94  31.0000  101786600
# 3  2012-05-23  31.37  32.50  31.36  32.0000   73600000
# 4  2012-05-24  32.95  33.21  31.77  33.0300   50237200

# %%
# Calculate moving average
ma_day = [5, 10, 20, 50]  # Common short-term and long-term windows
for ma in ma_day:
    column_name = f"MA for {ma} days"
    data[column_name] = data['Close'].rolling(window=ma).mean()

# Calculate Exponential moving average
for ma in ma_day:
    column_name = f"EMA for {ma} days"
    data[column_name] = data['Close'].ewm(span=ma, adjust=False).mean()

# Volatility (Standard Deviation): Capture price fluctuations:
# for ma in ma_day:
#     column_name = f"Volatility_{ma}d"
#     data[column_name] = data['Close'].rolling(window=ma).std()

# Calculate RSI
def compute_RSI(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data['RSI_14'] = compute_RSI(data)

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#             Date    Open     High       Low     Close     Volume  \
# 0     2012-05-18   42.05   45.000   38.0000   38.2318  573576400
# 1     2012-05-21   36.53   36.660   33.0000   34.0300  168192700
# 2     2012-05-22   32.61   33.590   30.9400   31.0000  101786600
# 3     2012-05-23   31.37   32.500   31.3600   32.0000   73600000
# 4     2012-05-24   32.95   33.210   31.7700   33.0300   50237200
# ...          ...     ...      ...       ...       ...        ...
# 2668  2022-12-23  116.03  118.175  115.5350  118.0400   17796625
# 2669  2022-12-27  117.93  118.600  116.0501  116.8800   21392311
# 2670  2022-12-28  116.25  118.150  115.5100  115.6200   19612473
# 2671  2022-12-29  116.40  121.030  115.7700  120.2600   22366192
# 2672  2022-12-30  118.16  120.420  117.7400  120.3400   19583825
#
#       MA for 5 days  MA for 10 days  MA for 20 days  MA for 50 days  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4          33.65836             NaN             NaN             NaN
# ...             ...             ...             ...             ...
# 2668      117.29800         117.852         117.025        114.2838
# 2669      117.77800         118.069         117.430        114.0862
# 2670      117.48400         117.616         117.738        113.7178
# 2671      117.58400         117.483         117.846        113.4670
# 2672      118.22800         117.902         117.841        113.2092
#
#       EMA for 5 days  EMA for 10 days  EMA for 20 days  EMA for 50 days  \
# 0          38.231800        38.231800        38.231800        38.231800
# 1          36.831200        37.467836        37.831629        38.067024
# 2          34.887467        36.291866        37.180997        37.789885
# 3          33.924978        35.511527        36.687569        37.562831
# 4          33.626652        35.060340        36.339229        37.385073
# ...              ...              ...              ...              ...
# 2668      117.800705       117.531164       116.637103       119.704974
# 2669      117.493804       117.412770       116.660236       119.594191
# 2670      116.869202       117.086812       116.561166       119.438340
# 2671      117.999468       117.663755       116.913436       119.470562
# 2672      118.779646       118.150345       117.239776       119.504658
#
#          RSI_14      MACD
# 0           NaN  0.000000
# 1           NaN -0.335186
# 2           NaN -0.835686
# 3           NaN -1.138520
# 4           NaN -1.280644
# ...         ...       ...
# 2668  44.652862  0.867627
# 2669  54.070796  0.765449
# 2670  52.416357  0.576159
# 2671  56.451191  0.791432
# 2672  55.885472  0.957455
#
# [2673 rows x 16 columns]
#                   count          mean           std           min  \
# Open             2673.0  1.479633e+02  8.696828e+01  1.808000e+01
# High             2673.0  1.498468e+02  8.805465e+01  1.827000e+01
# Low              2673.0  1.460862e+02  8.591529e+01  1.755000e+01
# Close            2673.0  1.479917e+02  8.699929e+01  1.772900e+01
# Volume           2673.0  3.115405e+07  2.721709e+07  5.913066e+06
# MA for 5 days    2669.0  1.480981e+02  8.692966e+01  1.846140e+01
# MA for 10 days   2664.0  1.482359e+02  8.686269e+01  1.877955e+01
# MA for 20 days   2654.0  1.485193e+02  8.673551e+01  1.925918e+01
# MA for 50 days   2624.0  1.493997e+02  8.630554e+01  2.017572e+01
# EMA for 5 days   2673.0  1.479314e+02  8.694024e+01  1.846579e+01
# EMA for 10 days  2673.0  1.478571e+02  8.690014e+01  1.890858e+01
# EMA for 20 days  2673.0  1.477109e+02  8.681879e+01  1.968711e+01
# EMA for 50 days  2673.0  1.472468e+02  8.654123e+01  2.106646e+01
# RSI_14           2660.0  5.344210e+01  1.577691e+01  9.768073e+00
# MACD             2673.0  2.043057e-01  4.256432e+00 -2.904631e+01
#
#                           25%           50%           75%           max
# Open             7.780000e+01  1.422600e+02  1.913600e+02  3.816800e+02
# High             7.853000e+01  1.445600e+02  1.940300e+02  3.843300e+02
# Low              7.705000e+01  1.408700e+02  1.884700e+02  3.788100e+02
# Close            7.783000e+01  1.422800e+02  1.912900e+02  3.821800e+02
# Volume           1.618928e+07  2.313342e+07  3.599420e+07  5.735764e+08
# MA for 5 days    7.780600e+01  1.422620e+02  1.913780e+02  3.790300e+02
# MA for 10 days   7.777912e+01  1.418685e+02  1.917312e+02  3.786580e+02
# MA for 20 days   7.751544e+01  1.434165e+02  1.920813e+02  3.734220e+02
# MA for 50 days   7.745560e+01  1.471485e+02  1.906790e+02  3.637544e+02
# EMA for 5 days   7.757111e+01  1.420655e+02  1.913073e+02  3.782458e+02
# EMA for 10 days  7.745753e+01  1.418166e+02  1.908980e+02  3.763954e+02
# EMA for 20 days  7.711146e+01  1.424947e+02  1.903275e+02  3.728644e+02
# EMA for 50 days  7.669829e+01  1.454013e+02  1.891680e+02  3.629571e+02
# RSI_14           4.233863e+01  5.403817e+01  6.516629e+01  9.498106e+01
# MACD            -8.841952e-01  6.689780e-01  2.167294e+00  1.363001e+01

# %%
data.dropna(inplace=True)
data.head(500)
# Out:
#            Date    Open   High     Low  Close     Volume  MA for 5 days  \
# 49   2012-07-30  23.995  24.04  23.030  23.15   29285900       26.29800
# 50   2012-07-31  23.370  23.37  21.610  21.71   56179400       24.95000
# 51   2012-08-01  21.500  21.58  20.840  20.88   44604400       23.25800
# 52   2012-08-02  20.770  20.84  19.820  20.04   56374500       21.89700
# 53   2012-08-03  20.360  22.16  19.900  21.09   80647000       21.37400
# ..          ...     ...    ...     ...    ...        ...            ...
# 544  2014-07-21  68.810  69.96  68.500  69.40   49431600       67.81096
# 545  2014-07-22  69.760  69.77  68.610  69.27   40301800       68.23196
# 546  2014-07-23  69.740  71.33  69.610  71.29   77435900       68.95796
# 547  2014-07-24  75.960  76.74  74.510  74.98  124006900       70.67198
# 548  2014-07-25  74.990  75.67  74.662  75.19   45823100       72.02600
#
#      MA for 10 days  MA for 20 days  MA for 50 days  EMA for 5 days  \
# 49         27.52000       29.237800       29.838636       25.546291
# 50         26.88200       28.784750       29.508200       24.267527
# 51         26.05900       28.268750       29.245200       23.138351
# 52         25.16300       27.697250       29.026000       22.105568
# 53         24.39600       27.165250       28.807800       21.767045
# ..              ...             ...             ...             ...
# 544        66.58973       66.626865       64.001716       68.007206
# 545        67.24073       66.821865       64.242316       68.428138
# 546        67.87273       67.100365       64.471516       69.382092
# 547        68.88348       67.477365       64.774516       71.248061
# 548        69.76848       67.880365       65.093716       72.562041
#
#      EMA for 10 days  EMA for 20 days  EMA for 50 days     RSI_14      MACD
# 49         27.046144        28.449746        30.538853  15.733114 -1.525536
# 50         26.075936        27.807865        30.192623  14.602446 -1.869091
# 51         25.131220        27.148068        29.827422  13.890909 -2.183168
# 52         24.205544        26.471110        29.443602  13.172414 -2.471369
# 53         23.639081        25.958623        29.116010  22.638623 -2.585243
# ..               ...              ...              ...        ...       ...
# 544        67.283914        66.478537        64.769416  56.251778  1.037495
# 545        67.645020        66.744391        64.945909  53.726471  1.134074
# 546        68.307744        67.177306        65.194697  64.538726  1.357958
# 547        69.520881        67.920420        65.578435  71.536342  1.812249
# 548        70.551630        68.612761        65.955359  75.534944  2.164275
#
# [500 rows x 16 columns]

# %%
# updated Code

feature_columns = [
    'Open',           # Opening price
    'High',           # Daily high price
    'Low',            # Daily low price
    'Close',          # Closing price (most important feature)
    'Volume',         # Trading volume
    'MA for 5 days',  # 5-day moving average
    'MA for 10 days', # 10-day moving average
    'MA for 20 days', # 20-day moving average
    'MA for 50 days', # 50-day moving average
    'EMA for 5 days', # 5-day exponential moving average
    'EMA for 10 days',# 10-day exponential moving average
    'EMA for 20 days',# 20-day exponential moving average
    'EMA for 50 days',# 50-day exponential moving average
    'RSI_14',         # Relative Strength Index (14-day)
    'MACD'            # Moving Average Convergence Divergence
]

from sklearn.model_selection import train_test_split
import numpy as np

X = []
Y = []
window_size = 15

# Iterating through the dataset to create inputs and targets
for i in range(1, len(df) - window_size - 1, 1):
    first_close = df.iloc[i, df.columns.get_loc('Close')]  # Normalize using "Close" price
    temp = []
    temp2 = []
    
    for j in range(window_size):
        # Normalize each feature in the feature_columns list
        normalized_features = []
        for feature in feature_columns:
            if feature == 'Close':
                # Normalize "Close" relative to the first_close
                normalized_value = (df.iloc[i + j, df.columns.get_loc(feature)] - first_close) / first_close
            else:
                # For other features, normalize them directly (or use their raw values if normalization isn't required)
                normalized_value = df.iloc[i + j, df.columns.get_loc(feature)]
            normalized_features.append(normalized_value)
        
        # Append the normalized features for this time step
        temp.append(normalized_features)
    
    # Calculate the target (normalized change in "Close" price)
    target = (df.iloc[i + window_size, df.columns.get_loc('Close')] - first_close) / first_close
    temp2.append(target)
    
    # Append the input and target to X and Y
    X.append(np.array(temp))  # Each sample has shape (window_size, len(feature_columns))
    Y.append(np.array(temp2).reshape(1, 1))

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# Converting lists to numpy arrays
train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

# Verify the shape of train_X
print("Shape of train_X before reshaping:", train_X.shape)

# Reshaping the data for CNN models
# Assuming train_X has shape (num_samples, window_size, num_features)
train_X = train_X.reshape(train_X.shape[0], 1, train_X.shape[1], train_X.shape[2])  
test_X = test_X.reshape(test_X.shape[0], 1, test_X.shape[1], test_X.shape[2])

# Printing the number of training and testing samples
print("Shape of train_X after reshaping:", train_X.shape)
print("Shape of test_X after reshaping:", test_X.shape)
print("Number of training samples:", len(train_X))
print("Number of testing samples:", len(test_X))
# Out:
# Shape of train_X before reshaping: (2085, 15, 15)
# Shape of train_X after reshaping: (2085, 1, 15, 15)
# Shape of test_X after reshaping: (522, 1, 15, 15)
# Number of training samples: 2085
# Number of testing samples: 522

# %%
# Check if there are any NaN values

print(np.isnan(train_X).any(), np.isnan(train_Y).any())
print(np.isinf(train_X).any(), np.isinf(train_Y).any())
# Out:
# False False
# False False

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Create the model
# model = tf.keras.Sequential()

# # Enhanced CNN layers with BatchNormalization and LeakyReLU
# model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                                input_shape=(None, 100, 1))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
#                                kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
# model.add(TimeDistributed(MaxPooling1D(2)))

# model.add(TimeDistributed(Flatten()))

# # Enhanced LSTM layers (removed clip_norm parameter)
# model.add(Bidirectional(LSTM(128, return_sequences=True, 
#                             kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                             recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(BatchNormalization())
# model.add(Dropout(0.4))

# model.add(Bidirectional(LSTM(64, return_sequences=False,
#                             kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
#                             recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
# model.add(BatchNormalization())
# model.add(Dropout(0.4))

# # Dense layers with regularization
# model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
# model.add(BatchNormalization())
# model.add(LeakyReLU(alpha=0.1))
# model.add(Dropout(0.2))

# model.add(Dense(1, activation='linear'))

# # Optimizer with gradient clipping (clipnorm moved here)
# optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

# model.compile(optimizer=optimizer,
#              loss='mse',
#              metrics=['mse', 'mae'])

# # Define callbacks
# callbacks = [
#     EarlyStopping(
#         monitor='val_loss',
#         patience=10,
#         restore_best_weights=True
#     ),
#     ReduceLROnPlateau(
#         monitor='val_loss',
#         factor=0.2,
#         patience=5,
#         min_lr=1e-6
#     )
# ]

# # Train the model
# history = model.fit(
#     train_X, 
#     train_Y,
#     validation_data=(test_X, test_Y),
#     epochs=100,
#     batch_size=32,
#     callbacks=callbacks,
#     verbose=1,
#     shuffle=True
# )

# Adding an Attention Layer
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.nn.tanh(tf.matmul(x, self.W) + self.b)
        at = tf.nn.softmax(et, axis=1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

# Create the model
model = tf.keras.Sequential()

# Enhanced CNN layers with BatchNormalization and LeakyReLU
model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same', 
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                               input_shape=(None, 100, 1))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(128, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Conv1D(64, kernel_size=3, padding='same',
                               kernel_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(LeakyReLU(alpha=0.1)))
model.add(TimeDistributed(MaxPooling1D(2)))

model.add(TimeDistributed(Flatten()))

# Enhanced LSTM layers (removed clip_norm parameter)
model.add(Bidirectional(LSTM(128, return_sequences=True, 
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Bidirectional(LSTM(64, return_sequences=True,  # Set return_sequences=True for Attention
                            kernel_regularizer=L1L2(l1=1e-5, l2=1e-4),
                            recurrent_regularizer=L1L2(l1=1e-5, l2=1e-4))))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Add Attention Layer here
model.add(AttentionLayer())

# Dense layers with regularization
model.add(Dense(32, kernel_regularizer=L1L2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

# Optimizer with gradient clipping (clipnorm moved here)
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

model.compile(optimizer=optimizer,
             loss='mse',
             metrics=['mse', 'mae'])

# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6
    )
]

# Train the model
history = model.fit(
    train_X, 
    train_Y,
    validation_data=(test_X, test_Y),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/100
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# WARNING:tensorflow:From c:\Users\timoz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - loss: 0.9003 - mae: 0.5949 - mse: 0.6084 - val_loss: 0.2193 - val_mae: 0.0786 - val_mse: 0.0124 - learning_rate: 0.0010
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4058 - mae: 0.3563 - mse: 0.2070 - val_loss: 0.1981 - val_mae: 0.0726 - val_mse: 0.0097 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3033 - mae: 0.2685 - mse: 0.1159 - val_loss: 0.1951 - val_mae: 0.0728 - val_mse: 0.0100 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2614 - mae: 0.2150 - mse: 0.0769 - val_loss: 0.1932 - val_mae: 0.0746 - val_mse: 0.0108 - learning_rate: 0.0010
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2396 - mae: 0.1850 - mse: 0.0579 - val_loss: 0.1898 - val_mae: 0.0735 - val_mse: 0.0104 - learning_rate: 0.0010
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2243 - mae: 0.1646 - mse: 0.0457 - val_loss: 0.1882 - val_mae: 0.0761 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2064 - mae: 0.1369 - mse: 0.0314 - val_loss: 0.1842 - val_mae: 0.0769 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1980 - mae: 0.1264 - mse: 0.0268 - val_loss: 0.1801 - val_mae: 0.0758 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1885 - mae: 0.1123 - mse: 0.0213 - val_loss: 0.1763 - val_mae: 0.0769 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1822 - mae: 0.1049 - mse: 0.0192 - val_loss: 0.1721 - val_mae: 0.0768 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1744 - mae: 0.0945 - mse: 0.0158 - val_loss: 0.1679 - val_mae: 0.0786 - val_mse: 0.0126 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1685 - mae: 0.0900 - mse: 0.0144 - val_loss: 0.1626 - val_mae: 0.0759 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1614 - mae: 0.0826 - mse: 0.0119 - val_loss: 0.1578 - val_mae: 0.0758 - val_mse: 0.0118 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1563 - mae: 0.0805 - mse: 0.0116 - val_loss: 0.1531 - val_mae: 0.0765 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1507 - mae: 0.0781 - mse: 0.0108 - val_loss: 0.1485 - val_mae: 0.0781 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1444 - mae: 0.0700 - mse: 0.0093 - val_loss: 0.1435 - val_mae: 0.0767 - val_mse: 0.0121 - learning_rate: 0.0010
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1398 - mae: 0.0735 - mse: 0.0096 - val_loss: 0.1386 - val_mae: 0.0769 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1339 - mae: 0.0688 - mse: 0.0086 - val_loss: 0.1331 - val_mae: 0.0755 - val_mse: 0.0116 - learning_rate: 0.0010
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1280 - mae: 0.0654 - mse: 0.0077 - val_loss: 0.1286 - val_mae: 0.0766 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1238 - mae: 0.0684 - mse: 0.0084 - val_loss: 0.1232 - val_mae: 0.0757 - val_mse: 0.0114 - learning_rate: 0.0010
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1190 - mae: 0.0673 - mse: 0.0085 - val_loss: 0.1194 - val_mae: 0.0768 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1135 - mae: 0.0634 - mse: 0.0077 - val_loss: 0.1144 - val_mae: 0.0773 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1083 - mae: 0.0621 - mse: 0.0073 - val_loss: 0.1097 - val_mae: 0.0774 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1044 - mae: 0.0645 - mse: 0.0081 - val_loss: 0.1048 - val_mae: 0.0762 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0991 - mae: 0.0620 - mse: 0.0074 - val_loss: 0.1000 - val_mae: 0.0755 - val_mse: 0.0118 - learning_rate: 0.0010
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0942 - mae: 0.0616 - mse: 0.0071 - val_loss: 0.0961 - val_mae: 0.0775 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0903 - mae: 0.0627 - mse: 0.0075 - val_loss: 0.0923 - val_mae: 0.0785 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0858 - mae: 0.0636 - mse: 0.0074 - val_loss: 0.0876 - val_mae: 0.0770 - val_mse: 0.0124 - learning_rate: 0.0010
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0808 - mae: 0.0595 - mse: 0.0065 - val_loss: 0.0839 - val_mae: 0.0775 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0768 - mae: 0.0598 - mse: 0.0066 - val_loss: 0.0797 - val_mae: 0.0771 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0735 - mae: 0.0608 - mse: 0.0073 - val_loss: 0.0756 - val_mae: 0.0772 - val_mse: 0.0122 - learning_rate: 0.0010
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0706 - mae: 0.0639 - mse: 0.0082 - val_loss: 0.0716 - val_mae: 0.0766 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0650 - mae: 0.0579 - mse: 0.0063 - val_loss: 0.0697 - val_mae: 0.0806 - val_mse: 0.0135 - learning_rate: 0.0010
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0618 - mae: 0.0581 - mse: 0.0065 - val_loss: 0.0646 - val_mae: 0.0766 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0587 - mae: 0.0589 - mse: 0.0067 - val_loss: 0.0626 - val_mae: 0.0778 - val_mse: 0.0130 - learning_rate: 0.0010
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0561 - mae: 0.0628 - mse: 0.0072 - val_loss: 0.0591 - val_mae: 0.0777 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0526 - mae: 0.0607 - mse: 0.0068 - val_loss: 0.0571 - val_mae: 0.0782 - val_mse: 0.0133 - learning_rate: 0.0010
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0495 - mae: 0.0585 - mse: 0.0065 - val_loss: 0.0533 - val_mae: 0.0766 - val_mse: 0.0123 - learning_rate: 0.0010
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0471 - mae: 0.0596 - mse: 0.0067 - val_loss: 0.0497 - val_mae: 0.0760 - val_mse: 0.0114 - learning_rate: 0.0010
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0444 - mae: 0.0592 - mse: 0.0066 - val_loss: 0.0490 - val_mae: 0.0780 - val_mse: 0.0130 - learning_rate: 0.0010
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0416 - mae: 0.0576 - mse: 0.0062 - val_loss: 0.0482 - val_mae: 0.0796 - val_mse: 0.0145 - learning_rate: 0.0010
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0395 - mae: 0.0567 - mse: 0.0063 - val_loss: 0.0426 - val_mae: 0.0749 - val_mse: 0.0110 - learning_rate: 0.0010
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0377 - mae: 0.0584 - mse: 0.0066 - val_loss: 0.0426 - val_mae: 0.0788 - val_mse: 0.0130 - learning_rate: 0.0010
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0351 - mae: 0.0575 - mse: 0.0061 - val_loss: 0.0425 - val_mae: 0.0807 - val_mse: 0.0148 - learning_rate: 0.0010
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0338 - mae: 0.0576 - mse: 0.0065 - val_loss: 0.0393 - val_mae: 0.0785 - val_mse: 0.0133 - learning_rate: 0.0010
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0313 - mae: 0.0559 - mse: 0.0058 - val_loss: 0.0378 - val_mae: 0.0778 - val_mse: 0.0135 - learning_rate: 0.0010
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0302 - mae: 0.0575 - mse: 0.0062 - val_loss: 0.0352 - val_mae: 0.0765 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0284 - mae: 0.0576 - mse: 0.0060 - val_loss: 0.0361 - val_mae: 0.0798 - val_mse: 0.0148 - learning_rate: 0.0010
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0278 - mae: 0.0600 - mse: 0.0067 - val_loss: 0.0324 - val_mae: 0.0772 - val_mse: 0.0124 - learning_rate: 0.0010
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0254 - mae: 0.0550 - mse: 0.0058 - val_loss: 0.0298 - val_mae: 0.0744 - val_mse: 0.0112 - learning_rate: 0.0010
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0245 - mae: 0.0570 - mse: 0.0062 - val_loss: 0.0317 - val_mae: 0.0793 - val_mse: 0.0141 - learning_rate: 0.0010
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0235 - mae: 0.0568 - mse: 0.0063 - val_loss: 0.0305 - val_mae: 0.0798 - val_mse: 0.0140 - learning_rate: 0.0010
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0220 - mae: 0.0557 - mse: 0.0058 - val_loss: 0.0270 - val_mae: 0.0758 - val_mse: 0.0116 - learning_rate: 0.0010
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0210 - mae: 0.0564 - mse: 0.0058 - val_loss: 0.0271 - val_mae: 0.0770 - val_mse: 0.0125 - learning_rate: 0.0010
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0202 - mae: 0.0568 - mse: 0.0060 - val_loss: 0.0255 - val_mae: 0.0754 - val_mse: 0.0119 - learning_rate: 0.0010
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0197 - mae: 0.0560 - mse: 0.0061 - val_loss: 0.0232 - val_mae: 0.0726 - val_mse: 0.0101 - learning_rate: 0.0010
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0188 - mae: 0.0563 - mse: 0.0059 - val_loss: 0.0291 - val_mae: 0.0821 - val_mse: 0.0169 - learning_rate: 0.0010
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0179 - mae: 0.0562 - mse: 0.0060 - val_loss: 0.0291 - val_mae: 0.0842 - val_mse: 0.0177 - learning_rate: 0.0010
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0176 - mae: 0.0571 - mse: 0.0063 - val_loss: 0.0247 - val_mae: 0.0800 - val_mse: 0.0139 - learning_rate: 0.0010
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0168 - mae: 0.0558 - mse: 0.0059 - val_loss: 0.0244 - val_mae: 0.0794 - val_mse: 0.0136 - learning_rate: 0.0010
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0163 - mae: 0.0554 - mse: 0.0058 - val_loss: 0.0237 - val_mae: 0.0782 - val_mse: 0.0135 - learning_rate: 0.0010
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0160 - mae: 0.0558 - mse: 0.0061 - val_loss: 0.0225 - val_mae: 0.0782 - val_mse: 0.0132 - learning_rate: 2.0000e-04
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - mae: 0.0546 - mse: 0.0053 - val_loss: 0.0216 - val_mae: 0.0775 - val_mse: 0.0128 - learning_rate: 2.0000e-04
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0141 - mae: 0.0537 - mse: 0.0053 - val_loss: 0.0201 - val_mae: 0.0754 - val_mse: 0.0116 - learning_rate: 2.0000e-04
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0137 - mae: 0.0537 - mse: 0.0052 - val_loss: 0.0215 - val_mae: 0.0781 - val_mse: 0.0133 - learning_rate: 2.0000e-04
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0136 - mae: 0.0540 - mse: 0.0054 - val_loss: 0.0194 - val_mae: 0.0747 - val_mse: 0.0114 - learning_rate: 2.0000e-04
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0134 - mae: 0.0534 - mse: 0.0054 - val_loss: 0.0221 - val_mae: 0.0790 - val_mse: 0.0142 - learning_rate: 2.0000e-04
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0131 - mae: 0.0534 - mse: 0.0053 - val_loss: 0.0204 - val_mae: 0.0773 - val_mse: 0.0127 - learning_rate: 2.0000e-04
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0130 - mae: 0.0530 - mse: 0.0053 - val_loss: 0.0183 - val_mae: 0.0736 - val_mse: 0.0108 - learning_rate: 2.0000e-04
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0128 - mae: 0.0541 - mse: 0.0053 - val_loss: 0.0227 - val_mae: 0.0811 - val_mse: 0.0152 - learning_rate: 2.0000e-04
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0125 - mae: 0.0532 - mse: 0.0051 - val_loss: 0.0186 - val_mae: 0.0745 - val_mse: 0.0114 - learning_rate: 2.0000e-04
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0127 - mae: 0.0541 - mse: 0.0054 - val_loss: 0.0201 - val_mae: 0.0774 - val_mse: 0.0129 - learning_rate: 2.0000e-04
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0125 - mae: 0.0543 - mse: 0.0054 - val_loss: 0.0209 - val_mae: 0.0779 - val_mse: 0.0139 - learning_rate: 2.0000e-04
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0117 - mae: 0.0510 - mse: 0.0047 - val_loss: 0.0209 - val_mae: 0.0789 - val_mse: 0.0140 - learning_rate: 2.0000e-04
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0117 - mae: 0.0517 - mse: 0.0049 - val_loss: 0.0202 - val_mae: 0.0782 - val_mse: 0.0135 - learning_rate: 4.0000e-05
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - mae: 0.0491 - mse: 0.0042 - val_loss: 0.0203 - val_mae: 0.0786 - val_mse: 0.0137 - learning_rate: 4.0000e-05
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0111 - mae: 0.0503 - mse: 0.0045 - val_loss: 0.0203 - val_mae: 0.0789 - val_mse: 0.0137 - learning_rate: 4.0000e-05
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0111 - mae: 0.0502 - mse: 0.0046 - val_loss: 0.0208 - val_mae: 0.0797 - val_mse: 0.0143 - learning_rate: 4.0000e-05
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0110 - mae: 0.0508 - mse: 0.0045 - val_loss: 0.0209 - val_mae: 0.0797 - val_mse: 0.0145 - learning_rate: 4.0000e-05

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

print("Training Loss:", history.history.get('loss', []))
print("Validation Loss:", history.history.get('val_loss', []))
# Out:
# Training Loss: [0.7292554974555969, 0.3741725981235504, 0.29006925225257874, 0.2558627724647522, 0.2338227480649948, 0.21863673627376556, 0.20480157434940338, 0.19423812627792358, 0.18697455525398254, 0.17958109080791473, 0.17338834702968597, 0.16683678328990936, 0.16019952297210693, 0.15457139909267426, 0.149093896150589, 0.14335907995700836, 0.1383274644613266, 0.13281719386577606, 0.12738679349422455, 0.12246976792812347, 0.11747495085000992, 0.11250174045562744, 0.10759307444095612, 0.10316182672977448, 0.09786631166934967, 0.09339246898889542, 0.08896556496620178, 0.08466743677854538, 0.08017407357692719, 0.07624530047178268, 0.07260243594646454, 0.0685424730181694, 0.06476712971925735, 0.06118941307067871, 0.05793534964323044, 0.05491418391466141, 0.05196014419198036, 0.04893337935209274, 0.046103335916996, 0.043535538017749786, 0.04140276461839676, 0.03901032358407974, 0.037176404148340225, 0.03469841182231903, 0.03314094617962837, 0.031157122924923897, 0.02963958866894245, 0.028129495680332184, 0.02722802199423313, 0.02551281452178955, 0.024322450160980225, 0.02300131320953369, 0.021805550903081894, 0.02092384174466133, 0.0199472326785326, 0.019302427768707275, 0.018918374553322792, 0.01777821220457554, 0.017230981960892677, 0.01721457578241825, 0.016523858532309532, 0.015744734555482864, 0.014540725387632847, 0.014253951609134674, 0.013821757398545742, 0.013323958031833172, 0.01327706128358841, 0.012916290201246738, 0.012920171953737736, 0.012741615064442158, 0.012696369551122189, 0.012335740029811859, 0.012293227016925812, 0.011863582767546177, 0.011593402363359928, 0.01114694308489561, 0.010901624336838722, 0.01093172188848257, 0.011048042215406895]
# Validation Loss: [0.21926988661289215, 0.19813646376132965, 0.19509895145893097, 0.19316096603870392, 0.18976294994354248, 0.18819190561771393, 0.1841718703508377, 0.1801103949546814, 0.17628037929534912, 0.17208723723888397, 0.16791114211082458, 0.1625821590423584, 0.15778012573719025, 0.15308329463005066, 0.148513525724411, 0.14348450303077698, 0.13863994181156158, 0.13311251997947693, 0.12858060002326965, 0.12319791316986084, 0.11944195628166199, 0.11442431807518005, 0.10971492528915405, 0.10476924479007721, 0.1000402569770813, 0.09611429274082184, 0.09231910854578018, 0.08761923760175705, 0.08393672108650208, 0.07969071716070175, 0.0755968913435936, 0.07159242033958435, 0.06971177458763123, 0.06461766362190247, 0.06264904886484146, 0.059056010097265244, 0.05707891657948494, 0.05332228168845177, 0.04971935227513313, 0.048977989703416824, 0.048171982169151306, 0.042601555585861206, 0.04260655492544174, 0.042470186948776245, 0.039301108568906784, 0.037828460335731506, 0.03521456569433212, 0.03607860580086708, 0.032446056604385376, 0.029761338606476784, 0.031685758382081985, 0.03049595095217228, 0.026955965906381607, 0.027133584022521973, 0.025462377816438675, 0.02315257489681244, 0.029137706384062767, 0.029058218002319336, 0.02472079172730446, 0.02442292869091034, 0.02372615784406662, 0.02247334085404873, 0.021608363837003708, 0.02013569511473179, 0.021525241434574127, 0.019379546865820885, 0.02206999994814396, 0.020429274067282677, 0.01832243613898754, 0.02265927381813526, 0.01864977926015854, 0.020062394440174103, 0.020908009260892868, 0.020874042063951492, 0.020200785249471664, 0.020282430574297905, 0.020286226645112038, 0.020772112533450127, 0.020917462185025215]

# %%
# mse
plt.plot(history.history['mse'], label='train mse')
plt.plot(history.history['val_mse'], label='val mse')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# mae
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mae: 0.0540 - mse: 0.0059
# [0.01832243613898754, 0.010758268646895885, 0.07357117533683777]

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: -0.020425
# R2 Score: -0.020425
# Max Error: 0.414245

# %%
# make predictions
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp


# # Get predictions from the model
# predicted = model.predict(test_X)

# # Reshape the actual test labels and predictions to ensure proper shape
# test_label = test_Y.reshape(-1,1)
# predicted = np.array(predicted[:,0]).reshape(-1,1)

# # Get the length of training data
# len_t = len(train_X)

# # Inverse transform the predictions and actual values
# # This loop is denormalizing/inverse scaling the predictions and actual values
# for j in range(len_t, len_t + len(test_X)):
#     temp = data.iloc[j,3]  # Getting the original scale factor
#     # Inverse transform actual values
#     test_label[j - len_t] = test_label[j - len_t] * temp + temp
#     # Inverse transform predictions
#     predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
def plot_predictions(test_label, predicted, title="Stock Price Prediction"):
    # Create figure and axis with specified size
    plt.figure(figsize=(15, 7))
    
    # Plot actual prices
    plt.plot(test_label, label='Actual Price', color='green')
    
    # Plot predicted prices
    plt.plot(predicted, label='Predicted Price', color='red')
    
    # Customize the plot
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add margins for better visibility
    plt.margins(x=0.02)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Show plot
    plt.show()

def plot_predictions_with_dates(test_label, predicted, dates, title="Stock Price Prediction"):
    plt.figure(figsize=(15, 6))
    
    # Plot with dates
    plt.plot(dates, test_label, label='Actual Price', color='blue', linewidth=2)
    plt.plot(dates, predicted, label='Predicted Price', color='red', linestyle='--', linewidth=2)
    
    plt.title(title, fontsize=16, pad=20)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price', fontsize=12)
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Format date axis
    plt.gcf().autofmt_xdate()  # Angle and align the tick labels
    
    plt.tight_layout()
    plt.show()

# %%
from scipy.signal import savgol_filter

def plot_predictions(test_label, predicted, title="Actual V Stock Price Prediction"):
    # Apply smoothing to both lines
    window_length = 5  # Must be odd; adjust this value to control smoothing amount
    polyorder = 1
    
    # Smooth both actual and predicted values
    test_label_smooth = savgol_filter(test_label.flatten(), window_length, polyorder)
    predicted_smooth = savgol_filter(predicted.flatten(), window_length, polyorder)
    
    plt.figure(figsize=(15, 6))
    
    # Plot smoothed lines
    plt.plot(test_label_smooth, label='Actual Price', color='red')
    plt.plot(predicted_smooth, label='Predicted Price', color='blue')
    
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_predictions(test_label, predicted, "Actual V Stock Price Prediction")

# %%
# Performance Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Calculate performance metrics
mse = mean_squared_error(test_label, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_label, predicted)
mape = np.mean(np.abs((test_label - predicted) / test_label)) * 100

# Print performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Squared Error (MSE): 603.682440862174
# Root Mean Squared Error (RMSE): 24.569949956444233
# Mean Absolute Error (MAE): 17.048035369937853
# Mean Absolute Percentage Error (MAPE): 8.17%

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Step 1: Evaluate baseline performance on the test set
baseline_predictions = model.predict(test_X)

# Reshape test_Y and baseline_predictions to 2D
test_Y_reshaped = test_Y.reshape(-1, 1)  # Shape: (batch_size * time_steps, 1)
baseline_predictions_reshaped = baseline_predictions.reshape(-1, 1)  # Shape: (batch_size * time_steps, 1)

# Compute baseline RMSE
baseline_rmse = np.sqrt(mean_squared_error(test_Y_reshaped, baseline_predictions_reshaped))
print(f"Baseline RMSE: {baseline_rmse}")

# Step 2: Initialize a dictionary to store feature importance
feature_importance = {feature: 0 for feature in feature_columns}

# Step 3: Compute permutation feature importance
for feature in feature_columns:
    # Shuffle the feature values in the test set
    shuffled_test_X = test_X.copy()
    shuffled_test_X[:, :, feature_columns.index(feature)] = np.random.permutation(
        shuffled_test_X[:, :, feature_columns.index(feature)]
    )
    
    # Predict with the shuffled test set
    shuffled_predictions = model.predict(shuffled_test_X)
    
    # Reshape shuffled_predictions to 2D
    shuffled_predictions_reshaped = shuffled_predictions.reshape(-1, 1)
    
    # Compute RMSE with the shuffled feature
    shuffled_rmse = np.sqrt(mean_squared_error(test_Y_reshaped, shuffled_predictions_reshaped))
    
    # Compute feature importance as the increase in RMSE
    feature_importance[feature] = shuffled_rmse - baseline_rmse

# Step 4: Sort features by importance
sorted_feature_importance = sorted(feature_importance.items(), key=lambda x: x[1], reverse=True)

# Step 5: Print feature importance
print("Feature Importance (Permutation):")
for feature, importance in sorted_feature_importance:
    print(f"{feature}: {importance:.4f}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Baseline RMSE: 262.0881122254162
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Feature Importance (Permutation):
# RSI_14: 0.0001
# MACD: -0.0001
# MA for 10 days: -0.0003
# EMA for 5 days: -0.0004
# EMA for 20 days: -0.0004
# EMA for 50 days: -0.0005
# EMA for 10 days: -0.0005
# MA for 50 days: -0.0006
# Open: -0.0006
# MA for 20 days: -0.0006
# Close: -0.0007
# MA for 5 days: -0.0010
# High: -0.0016
# Volume: -0.0017
# Low: -0.0020

# %%
import tensorflow as tf
import numpy as np

# Define a function to compute gradients
def compute_gradients(model, inputs):
    # Convert inputs to a TensorFlow tensor
    inputs = tf.convert_to_tensor(inputs, dtype=tf.float32)
    
    with tf.GradientTape() as tape:
        tape.watch(inputs)  # Watch the input tensor
        predictions = model(inputs)
    grads = tape.gradient(predictions, inputs)
    return grads

# Compute gradients for the test set
grads = compute_gradients(model, test_X)

# Aggregate gradients across batch and time steps
# Take the mean absolute value for each feature
gradient_importance = np.mean(np.abs(grads), axis=(0, 1))  # Shape: (num_features,)

# Ensure gradient_importance is a 1D array
if gradient_importance.ndim > 1:
    gradient_importance = np.mean(gradient_importance, axis=0)  # Flatten to 1D

# Map gradients to feature names
feature_importance = {feature: importance for feature, importance in zip(feature_columns, gradient_importance)}

# Sort features by importance
sorted_feature_importance = sorted(feature_importance.items(), key=lambda x: x[1], reverse=True)

# Print feature importance
print("Feature Importance (Gradient-Based):")
for feature, importance in sorted_feature_importance:
    print(f"{feature}: {importance:.4f}")
# Out:
# Feature Importance (Gradient-Based):
# Volume: 0.0000
# MA for 10 days: 0.0000
# EMA for 50 days: 0.0000
# Low: 0.0000
# MA for 20 days: 0.0000
# EMA for 10 days: 0.0000
# EMA for 20 days: 0.0000
# High: 0.0000
# MA for 50 days: 0.0000
# EMA for 5 days: 0.0000
# RSI_14: 0.0000
# Close: 0.0000
# MACD: 0.0000
# Open: 0.0000
# MA for 5 days: 0.0000

# %%
# Save the trained model
model.save('improved_model.h5')  # Saves the entire model (architecture, weights, and optimizer state)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
